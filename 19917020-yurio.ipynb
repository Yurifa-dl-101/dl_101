# %% [markdown]
# # Import the necessary libraries

# %%
import warnings
warnings.filterwarnings("default", category=DeprecationWarning)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, 
Input, Embedding
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping

# %% [markdown]
# # Load the data into Pandas dataframe

# %%
df = pd.read_csv('data/spam.csv',delimiter=',',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %% [markdown]
# # Understanding data distribution better

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %% [markdown]
# ## Create input and output vectors.
# ### Process the labels.

# %%
X = df.v2
Y = df.v1
le = LabelEncoder() # sklearn preprocessing object LabelEncoder to encode label
Y = le.fit_transform(Y) # fit and transform Y into encode label
Y = Y.reshape(-1,1)  # reshape value encode into -1(spam), 1(ham)

# %% [markdown]
# # Split into training and test data.

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
X_train
# Out:
# 5440        Thank you. do you generally date the brothas?
# 4013    Sorry, I can't text &amp; drive coherently, se...
# 1169    Msgs r not time pass.They silently say that I ...
# 4170    Pls what's the full name of joke's school cos ...
# 1670                                          Lmao!nice 1
#                               ...
# 5209    I know you are thinkin malaria. But relax, chi...
# 3130    LookAtMe!: Thanks for your purchase of a video...
# 3146    Oh thats late! Well have a good night and i wi...
# 3992    Nimbomsons. Yep phone knows that one. Obviousl...
# 1086                  I don't think he has spatula hands!
# Name: v2, Length: 4736, dtype: object

# %% [markdown]
# # Process the data
# - Tokenize the data and convert the `text` to `sequences`.
# - Add padding `to ensure` `that all the sequences` `have the same shape`.
# - There are many ways of taking the `max_len` `and here` `an arbitrary` `length of 150` `is chosen`.

# %%
max_words = 1000 # arbitrary set max words for corpus
max_len = 150 # maximum len for max shape array

# %%
tok = Tokenizer(num_words=max_words) # keras.preprocessing.text 
# Tokenizer object

tok.fit_on_texts(X_train) # Updates internal vocabulary based on a list 
# of texts

sequences = tok.texts_to_sequences(X_train) # Transforms each text in 
# texts to a sequence of integers

sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len) 
# keras.preprocessing sequence method to transforms a list of sequences 
# (lists of integers) into a 2D Numpy array of shape `(num_samples, 
# num_timesteps)`. `num_timesteps` is either the `maxlen` argument 
# if provided, or the length of the longest sequence otherwise

# %%
tok.index_word # 1000 words
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'in',
#  9: 'is',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'that',
#  21: 'now',
#  22: 'are',
#  23: 'so',
#  24: 'not',
#  25: 'but',
#  26: 'or',
#  27: 'can',
#  28: 'get',
#  29: 'do',
#  30: "i'm",
#  31: 'at',
#  32: 'with',
#  33: 'if',
#  34: 'ur',
#  35: 'will',
#  36: 'be',
#  37: 'just',
#  38: 'no',
#  39: 'we',
#  40: 'this',
#  41: '4',
#  42: 'up',
#  43: 'gt',
#  44: 'lt',
#  45: 'free',
#  46: 'when',
#  47: 'how',
#  48: 'from',
#  49: 'ok',
#  50: 'go',
#  51: 'out',
#  52: 'what',
#  53: 'all',
#  54: 'then',
#  55: 'know',
#  56: 'like',
#  57: 'good',
#  58: 'got',
#  59: 'come',
#  60: 'am',
#  61: 'was',
#  62: 'only',
#  63: 'time',
#  64: 'its',
#  65: 'love',
#  66: 'day',
#  67: 'there',
#  68: 'text',
#  69: 'he',
#  70: 'send',
#  71: 'want',
#  72: 'txt',
#  73: 'as',
#  74: 'going',
#  75: "i'll",
#  76: 'one',
#  77: 'need',
#  78: 'home',
#  79: 'about',
#  80: 'lor',
#  81: 'r',
#  82: 'sorry',
#  83: 'stop',
#  84: 'back',
#  85: 'by',
#  86: 'n',
#  87: 'still',
#  88: 'our',
#  89: 'today',
#  90: 'see',
#  91: 'k',
#  92: 'da',
#  93: 'reply',
#  94: 'new',
#  95: 'mobile',
#  96: 'phone',
#  97: 'tell',
#  98: 'she',
#  99: 'think',
#  100: 'later',
#  101: 'any',
#  102: 'dont',
#  103: 'take',
#  104: 'hi',
#  105: 'her',
#  106: "don't",
#  107: 'pls',
#  108: 'been',
#  109: 'please',
#  110: 'some',
#  111: 'ì',
#  112: 'week',
#  113: 'hey',
#  114: 'did',
#  115: 'has',
#  116: 'here',
#  117: 'dear',
#  118: '1',
#  119: 'well',
#  120: 'much',
#  121: 'they',
#  122: 'who',
#  123: 'oh',
#  124: 'hope',
#  125: 'night',
#  126: 'happy',
#  127: 'msg',
#  128: 'claim',
#  129: 'an',
#  130: 'where',
#  131: 'him',
#  132: 'make',
#  133: 'more',
#  134: 'great',
#  135: 'yes',
#  136: 'too',
#  137: 'c',
#  138: 'had',
#  139: 'wat',
#  140: 'd',
#  141: 'should',
#  142: 'message',
#  143: 'prize',
#  144: 'work',
#  145: 'right',
#  146: 'www',
#  147: "it's",
#  148: 'ask',
#  149: 'way',
#  150: 'after',
#  151: '3',
#  152: 'number',
#  153: 'say',
#  154: 'already',
#  155: 'amp',
#  156: 'tomorrow',
#  157: 'give',
#  158: 'yeah',
#  159: 'meet',
#  160: 'e',
#  161: 'babe',
#  162: 'said',
#  163: 'why',
#  164: 'doing',
#  165: 'really',
#  166: 'cash',
#  167: 'im',
#  168: 'find',
#  169: 'cos',
#  170: 'very',
#  171: 't',
#  172: 'them',
#  173: 'life',
#  174: 'thanks',
#  175: 'also',
#  176: 'would',
#  177: 'b',
#  178: 'last',
#  179: 'won',
#  180: 'miss',
#  181: 'morning',
#  182: 'pick',
#  183: 'let',
#  184: 'win',
#  185: 'over',
#  186: 'sent',
#  187: 'lol',
#  188: 'care',
#  189: 'com',
#  190: 'contact',
#  191: 'keep',
#  192: 'again',
#  193: 'sure',
#  194: 'before',
#  195: 'nokia',
#  196: 'next',
#  197: 'something',
#  198: 'anything',
#  199: 'us',
#  200: "i've",
#  201: 'around',
#  202: 'urgent',
#  203: 'even',
#  204: 'first',
#  205: 'uk',
#  206: 'cant',
#  207: 'wait',
#  208: 'many',
#  209: "can't",
#  210: 'gonna',
#  211: 'thing',
#  212: 'buy',
#  213: 'every',
#  214: 'soon',
#  215: 'went',
#  216: 'service',
#  217: 'min',
#  218: 'his',
#  219: '150p',
#  220: 'tonight',
#  221: 'someone',
#  222: '5',
#  223: 'sleep',
#  224: 'x',
#  225: 'feel',
#  226: 's',
#  227: 'leave',
#  228: 'always',
#  229: 'chat',
#  230: 'off',
#  231: "that's",
#  232: 'sms',
#  233: 'money',
#  234: 'were',
#  235: 'customer',
#  236: 'help',
#  237: 'per',
#  238: '50',
#  239: 'wan',
#  240: 'place',
#  241: 'down',
#  242: 'wish',
#  243: 'which',
#  244: 'v',
#  245: 'nice',
#  246: 'could',
#  247: 'getting',
#  248: '18',
#  249: 'guaranteed',
#  250: 'name',
#  251: 'other',
#  252: 'ìï',
#  253: 'ya',
#  254: 'fine',
#  255: 'told',
#  256: 'haha',
#  257: 'co',
#  258: 'may',
#  259: 'hello',
#  260: 'yet',
#  261: 'same',
#  262: 'people',
#  263: 'friends',
#  264: 'coming',
#  265: 'tone',
#  266: 'waiting',
#  267: 'try',
#  268: 'use',
#  269: 'done',
#  270: 'gud',
#  271: 'special',
#  272: 'talk',
#  273: 'live',
#  274: 'things',
#  275: '6',
#  276: 'thk',
#  277: "you're",
#  278: 'late',
#  279: 'lunch',
#  280: 'mins',
#  281: 'dun',
#  282: 'heart',
#  283: 'meeting',
#  284: 'house',
#  285: 'job',
#  286: 'man',
#  287: "didn't",
#  288: 'cs',
#  289: '16',
#  290: 'year',
#  291: 'cool',
#  292: 'person',
#  293: 'ready',
#  294: 'friend',
#  295: 'thats',
#  296: 'never',
#  297: 'few',
#  298: 'being',
#  299: 'holiday',
#  300: 'thought',
#  301: 'finish',
#  302: 'days',
#  303: 'draw',
#  304: 'yo',
#  305: 'better',
#  306: 'word',
#  307: 'class',
#  308: 'real',
#  309: 'god',
#  310: 'lot',
#  311: 'bit',
#  312: 'ill',
#  313: 'check',
#  314: 'mind',
#  315: 'long',
#  316: '7',
#  317: 'wk',
#  318: 'stuff',
#  319: 'yup',
#  320: 'line',
#  321: 'best',
#  322: 'end',
#  323: 'enjoy',
#  324: 'chance',
#  325: 'problem',
#  326: 'luv',
#  327: 'than',
#  328: 'eat',
#  329: 'shit',
#  330: 'awarded',
#  331: 'play',
#  332: 'smile',
#  333: 'trying',
#  334: 'half',
#  335: 'having',
#  336: 'world',
#  337: 'guess',
#  338: 'might',
#  339: 'account',
#  340: 'guys',
#  341: 'big',
#  342: 'y',
#  343: 'lar',
#  344: 'start',
#  345: 'month',
#  346: 'camera',
#  347: 'wanna',
#  348: 'receive',
#  349: 'latest',
#  350: 'sir',
#  351: 'nothing',
#  352: 'into',
#  353: 'å£1',
#  354: 'å£1000',
#  355: 'watching',
#  356: 'dat',
#  357: 'aight',
#  358: 'offer',
#  359: 'xxx',
#  360: 'ah',
#  361: 'girl',
#  362: 'car',
#  363: 'room',
#  364: 'birthday',
#  365: 'dunno',
#  366: '150ppm',
#  367: '1st',
#  368: 'because',
#  369: 'probably',
#  370: 'jus',
#  371: 'maybe',
#  372: 'video',
#  373: 'sweet',
#  374: 'dinner',
#  375: 'liao',
#  376: 'tv',
#  377: 'shows',
#  378: 'called',
#  379: 'another',
#  380: 'orange',
#  381: 'ever',
#  382: 'early',
#  383: 'look',
#  384: 'speak',
#  385: 'kiss',
#  386: 'left',
#  387: '9',
#  388: 'watch',
#  389: "he's",
#  390: 'apply',
#  391: 'minutes',
#  392: 'landline',
#  393: 'plan',
#  394: 'actually',
#  395: 'working',
#  396: 'office',
#  397: 'network',
#  398: 'easy',
#  399: 'shall',
#  400: 'cost',
#  401: 'put',
#  402: 'box',
#  403: 'does',
#  404: 'remember',
#  405: 'bed',
#  406: 'fun',
#  407: 'pa',
#  408: 'dad',
#  409: 'hear',
#  410: 'code',
#  411: 'den',
#  412: 'looking',
#  413: 'bad',
#  414: 'baby',
#  415: 'those',
#  416: 'bt',
#  417: 'thanx',
#  418: 'little',
#  419: 'once',
#  420: '000',
#  421: 'missing',
#  422: 'forgot',
#  423: 'pay',
#  424: 'll',
#  425: 'sexy',
#  426: 'boy',
#  427: 'sat',
#  428: 'award',
#  429: 'until',
#  430: 'join',
#  431: 'calls',
#  432: 'rate',
#  433: 'wif',
#  434: 'princess',
#  435: 'ringtone',
#  436: 'though',
#  437: 'wife',
#  438: 'hour',
#  439: 'details',
#  440: 'part',
#  441: 'weekend',
#  442: 'bus',
#  443: 'enough',
#  444: '2nd',
#  445: 'while',
#  446: 'says',
#  447: 'dis',
#  448: 'town',
#  449: 'reach',
#  450: 'thank',
#  451: 'entry',
#  452: 'selected',
#  453: 'texts',
#  454: '10',
#  455: 'asked',
#  456: 'quite',
#  457: 'everything',
#  458: 'means',
#  459: 'afternoon',
#  460: 'anyway',
#  461: 'collect',
#  462: "how's",
#  463: 'came',
#  464: 'wont',
#  465: 'between',
#  466: 'fuck',
#  467: 'school',
#  468: 'shopping',
#  469: 'hair',
#  470: 'bring',
#  471: 'most',
#  472: 'away',
#  473: 'goes',
#  474: 'mail',
#  475: 'm',
#  476: 'po',
#  477: 'plz',
#  478: 'worry',
#  479: "there's",
#  480: 'xmas',
#  481: 'missed',
#  482: 'tmr',
#  483: 'didnt',
#  484: 'alright',
#  485: 'change',
#  486: 'guy',
#  487: 'valid',
#  488: 'wen',
#  489: 'net',
#  490: 'messages',
#  491: 'tones',
#  492: 'wake',
#  493: 'able',
#  494: 'question',
#  495: 'important',
#  496: 'price',
#  497: 'without',
#  498: 'pain',
#  499: 'double',
#  500: 'hav',
#  501: 'evening',
#  502: 'true',
#  503: 'de',
#  504: 'weekly',
#  505: 'leh',
#  506: 'yesterday',
#  507: 'wanted',
#  508: 'yourself',
#  509: 'juz',
#  510: 'collection',
#  511: 'book',
#  512: 'times',
#  513: 'music',
#  514: 'stay',
#  515: 'til',
#  516: 'abt',
#  517: 'must',
#  518: 'show',
#  519: 'id',
#  520: 'online',
#  521: 'since',
#  522: 'leaving',
#  523: 'wid',
#  524: 'makes',
#  525: 'food',
#  526: 'else',
#  527: '10p',
#  528: 'run',
#  529: 'two',
#  530: 'answer',
#  531: 'g',
#  532: 'feeling',
#  533: '500',
#  534: 'todays',
#  535: 'attempt',
#  536: '8',
#  537: 'family',
#  538: 'saw',
#  539: 'friendship',
#  540: 'wot',
#  541: 'dude',
#  542: 'mob',
#  543: 'wants',
#  544: 're',
#  545: 'havent',
#  546: "we're",
#  547: 'test',
#  548: 'decimal',
#  549: 'gift',
#  550: 'made',
#  551: 'update',
#  552: 'date',
#  553: 'making',
#  554: "what's",
#  555: 'hurt',
#  556: 'coz',
#  557: 'plus',
#  558: 'haf',
#  559: 'goin',
#  560: 'together',
#  561: 'words',
#  562: 'driving',
#  563: 'ard',
#  564: 'okay',
#  565: "we'll",
#  566: 'yours',
#  567: 'games',
#  568: 'comes',
#  569: 'movie',
#  570: 'story',
#  571: 'lei',
#  572: "haven't",
#  573: "''",
#  574: 'trip',
#  575: 'å£2000',
#  576: '8007',
#  577: "won't",
#  578: 'thinking',
#  579: 'beautiful',
#  580: 'email',
#  581: 'neva',
#  582: 'hot',
#  583: 'okie',
#  584: 'finished',
#  585: 'these',
#  586: 'order',
#  587: 'shop',
#  588: 'ring',
#  589: 'eve',
#  590: 'busy',
#  591: 'bonus',
#  592: 'final',
#  593: 'vouchers',
#  594: 'old',
#  595: 'set',
#  596: 'tried',
#  597: 'drive',
#  598: 'full',
#  599: 'address',
#  600: 'awesome',
#  601: 'pics',
#  602: 'happen',
#  603: 'hours',
#  604: 'both',
#  605: 'services',
#  606: 'å£100',
#  607: 'cause',
#  608: 'bored',
#  609: 'sae',
#  610: 'http',
#  611: 'sch',
#  612: 'congrats',
#  613: '12hrs',
#  614: 'sleeping',
#  615: "c's",
#  616: 'saying',
#  617: 'available',
#  618: 'å£5000',
#  619: 'land',
#  620: 'believe',
#  621: 'pic',
#  622: 'pounds',
#  623: 'minute',
#  624: 'news',
#  625: 'angry',
#  626: 'oso',
#  627: 'rite',
#  628: 'unsubscribe',
#  629: 'charge',
#  630: 'post',
#  631: 'girls',
#  632: 'dreams',
#  633: 'calling',
#  634: 'either',
#  635: 'lose',
#  636: 'colour',
#  637: 'head',
#  638: 'private',
#  639: 'tot',
#  640: 'await',
#  641: 'lucky',
#  642: 'took',
#  643: 'delivery',
#  644: 'years',
#  645: 'sad',
#  646: 'taking',
#  647: 'hard',
#  648: "she's",
#  649: 'mean',
#  650: 'found',
#  651: 'nite',
#  652: 'gr8',
#  653: 'noe',
#  654: '750',
#  655: 'brother',
#  656: 'tomo',
#  657: 'top',
#  658: 'college',
#  659: 'msgs',
#  660: 'lets',
#  661: 'pretty',
#  662: 'face',
#  663: 'game',
#  664: 'ha',
#  665: 'huh',
#  666: 'don',
#  667: 'alone',
#  668: 'sis',
#  669: 'national',
#  670: 'chennai',
#  671: 'points',
#  672: 'sister',
#  673: 'row',
#  674: 'card',
#  675: 'company',
#  676: 'till',
#  677: 'kind',
#  678: 'opt',
#  679: 'loving',
#  680: 'second',
#  681: '\x89û',
#  682: 'simple',
#  683: 'tho',
#  684: 'club',
#  685: 'camcorder',
#  686: 'knw',
#  687: 'lesson',
#  688: 'worth',
#  689: 'pm',
#  690: 'everyone',
#  691: 'aft',
#  692: 'pobox',
#  693: 'needs',
#  694: 'tel',
#  695: 'parents',
#  696: '08000930705',
#  697: 'info',
#  698: 'whats',
#  699: 'walk',
#  700: 'crazy',
#  701: 'least',
#  702: 'gd',
#  703: 'nt',
#  704: 'happened',
#  705: 'sea',
#  706: 'visit',
#  707: 'drop',
#  708: 'anyone',
#  709: 'search',
#  710: 'light',
#  711: 'carlos',
#  712: 'operator',
#  713: 'darlin',
#  714: 'close',
#  715: 'decided',
#  716: 'statement',
#  717: '86688',
#  718: 'type',
#  719: 'hand',
#  720: 'mate',
#  721: 'å£500',
#  722: 'treat',
#  723: 'sounds',
#  724: 'prob',
#  725: 'drink',
#  726: 'pub',
#  727: 'mine',
#  728: "doesn't",
#  729: 'unlimited',
#  730: 'mobileupd8',
#  731: '08000839402',
#  732: 'open',
#  733: 'earlier',
#  734: 'congratulations',
#  735: 'chikku',
#  736: 'auction',
#  737: 'anytime',
#  738: 'hit',
#  739: 'smiling',
#  740: 'sun',
#  741: 'started',
#  742: 'finally',
#  743: 'whatever',
#  744: 'choose',
#  745: 'sunday',
#  746: 'frnd',
#  747: 'player',
#  748: 'secret',
#  749: 'lots',
#  750: 'sex',
#  751: 'smth',
#  752: '100',
#  753: 'å£250',
#  754: 'poly',
#  755: '11',
#  756: 'hungry',
#  757: 'smoke',
#  758: 'expires',
#  759: 'fone',
#  760: 'takes',
#  761: 'nope',
#  762: 'content',
#  763: 'side',
#  764: 'blue',
#  765: 'whole',
#  766: 'mates',
#  767: 'wil',
#  768: 'park',
#  769: 'savamob',
#  770: 'å£3',
#  771: "you've",
#  772: 'case',
#  773: 'xx',
#  774: 'fast',
#  775: 'fri',
#  776: 'o',
#  777: 'yr',
#  778: 'frm',
#  779: 'thinks',
#  780: 'father',
#  781: 'bout',
#  782: 'saturday',
#  783: 'lost',
#  784: 'wonderful',
#  785: 'winner',
#  786: 'log',
#  787: 'comp',
#  788: 'mum',
#  789: 'dating',
#  790: 'identifier',
#  791: 'cut',
#  792: 'press',
#  793: 'surprise',
#  794: 'complimentary',
#  795: 'outside',
#  796: 'fancy',
#  797: 'stupid',
#  798: 'mrng',
#  799: 'ipod',
#  800: 'ltd',
#  801: 'telling',
#  802: 'hmm',
#  803: 'lovely',
#  804: 'used',
#  805: 'each',
#  806: '0800',
#  807: 'offers',
#  808: 'wit',
#  809: 'mr',
#  810: 'break',
#  811: 'wkly',
#  812: 'mu',
#  813: 'phones',
#  814: 'meant',
#  815: 'boytoy',
#  816: 'fucking',
#  817: 'hee',
#  818: 'hows',
#  819: "'",
#  820: 'numbers',
#  821: 'å£350',
#  822: 'mom',
#  823: 'oredi',
#  824: 'b4',
#  825: 'friday',
#  826: 'ten',
#  827: 'listen',
#  828: 'credit',
#  829: 'mah',
#  830: 'john',
#  831: 'tired',
#  832: 'rs',
#  833: 'reveal',
#  834: 'feels',
#  835: 'bank',
#  836: 'sort',
#  837: 'dogging',
#  838: 'valued',
#  839: 'dnt',
#  840: 'orchard',
#  841: 'extra',
#  842: 'party',
#  843: 'loads',
#  844: 'forget',
#  845: 'enter',
#  846: 'wana',
#  847: 'read',
#  848: "you'll",
#  849: 'touch',
#  850: 'red',
#  851: 'suite342',
#  852: '2lands',
#  853: 'ugh',
#  854: '20',
#  855: 'motorola',
#  856: 'freemsg',
#  857: 'txts',
#  858: 'ans',
#  859: 'w',
#  860: 'hold',
#  861: 'almost',
#  862: 'within',
#  863: 'p',
#  864: 'gotta',
#  865: 'frnds',
#  866: 'their',
#  867: 'grins',
#  868: 'swing',
#  869: 'through',
#  870: 'å£2',
#  871: 'reason',
#  872: 'na',
#  873: 'sound',
#  874: 'tc',
#  875: 'goodmorning',
#  876: 'std',
#  877: 'wap',
#  878: 'mayb',
#  879: 'snow',
#  880: 'point',
#  881: 'gone',
#  882: 'hmmm',
#  883: 'slow',
#  884: 'rply',
#  885: 'ago',
#  886: 'reading',
#  887: 'seeing',
#  888: 'invited',
#  889: 'questions',
#  890: 'happiness',
#  891: 'ass',
#  892: 'caller',
#  893: 'weeks',
#  894: 'eh',
#  895: "wasn't",
#  896: 'far',
#  897: 'dream',
#  898: "isn't",
#  899: 'cum',
#  900: 'knew',
#  901: 'felt',
#  902: 'rakhesh',
#  903: 'india',
#  904: 'nyt',
#  905: 'course',
#  906: 'plans',
#  907: 'wine',
#  908: 'asking',
#  909: 'information',
#  910: "i'd",
#  911: 'leaves',
#  912: 'wrong',
#  913: 'bcoz',
#  914: 'bslvyl',
#  915: 'th',
#  916: 'rest',
#  917: 'rates',
#  918: 'area',
#  919: 'gas',
#  920: 'somewhere',
#  921: 'doin',
#  922: 'welcome',
#  923: 'kids',
#  924: 'charged',
#  925: '2003',
#  926: 'un',
#  927: 'fact',
#  928: 'gets',
#  929: 'write',
#  930: 'download',
#  931: 'age',
#  932: '30',
#  933: 'paper',
#  934: 'st',
#  935: 'couple',
#  936: 'computer',
#  937: 'christmas',
#  938: 'met',
#  939: 'whenever',
#  940: 'il',
#  941: 'via',
#  942: 'eg',
#  943: 'sell',
#  944: 'gn',
#  945: 'abiola',
#  946: 'normal',
#  947: 'call2optout',
#  948: 'myself',
#  949: 'song',
#  950: 'rock',
#  951: 'muz',
#  952: 'match',
#  953: 'reached',
#  954: 'shower',
#  955: 'kate',
#  956: 'laptop',
#  957: 'txting',
#  958: 'getzed',
#  959: 'sending',
#  960: '87066',
#  961: 'yar',
#  962: 'semester',
#  963: 'support',
#  964: 'link',
#  965: 'crave',
#  966: 'gym',
#  967: 'slowly',
#  968: 'rental',
#  969: 'own',
#  970: 'clean',
#  971: 'f',
#  972: 'admirer',
#  973: 'pass',
#  974: 'water',
#  975: 'small',
#  976: 'across',
#  977: '4u',
#  978: '2nite',
#  979: 'reward',
#  980: 'lovable',
#  981: 'confirm',
#  982: 'mon',
#  983: 'ex',
#  984: 'luck',
#  985: 'truth',
#  986: 'understand',
#  987: 'convey',
#  988: 'ringtones',
#  989: '00',
#  990: 'mrt',
#  991: 'ends',
#  992: 'discount',
#  993: 'usf',
#  994: 'doesnt',
#  995: 'askd',
#  996: 'otherwise',
#  997: '800',
#  998: 'redeemed',
#  999: '04',
#  1000: 'currently',
#  ...}

# %%
sequences # sequence of integers mapping words to tok corpus
# Out:
# [[450, 3, 29, 3, 552, 5],
#  [82, 1, 209, 68, 155, 597, 90, 3, 8],
#  [659,
#   81,
#   24,
#   63,
#   973,
#   121,
#   153,
#   20,
#   1,
#   60,
#   578,
#   15,
#   6,
#   145,
#   21,
#   7,
#   175,
#   553,
#   6,
#   99,
#   15,
#   10,
#   31,
#   701,
#   41,
#   4,
#   702,
#   703],
#  [107, 554, 5, 598, 250, 15, 467, 169, 8, 15, 2, 394, 36, 44, 43, 91, 107, 84],
#  [245, 118],
#  [69, 9, 336],
#  [231, 57, 660, 450, 309, 109, 5, 17, 749, 15, 974, 7, 17, 4, 579, 66],
#  [186, 10, 34, 580, 519, 214],
#  [24,
#   4,
#   310,
#   115,
#   704,
#   116,
#   834,
#   170,
#   9,
#   31,
#   105,
#   7,
#   9,
#   395,
#   749,
#   37,
#   10,
#   7,
#   8,
#   31,
#   5,
#   47,
#   17,
#   3,
#   108],
#  [29, 3, 55, 46, 408, 35, 36, 84],
#  [1, 71, 2, 90, 13, 661],
#  [103, 110, 975, 12],
#  [259,
#   11,
#   65,
#   47,
#   215,
#   13,
#   66,
#   22,
#   3,
#   484,
#   1,
#   99,
#   15,
#   3,
#   11,
#   373,
#   7,
#   70,
#   4,
#   2,
#   13,
#   282,
#   2,
#   3,
#   1,
#   65,
#   3,
#   27,
#   3,
#   409,
#   14,
#   1,
#   14,
#   976,
#   5,
#   705,
#   12,
#   53,
#   5,
#   336,
#   2,
#   409,
#   9,
#   7,
#   385],
#  [1, 337, 3, 246, 36, 73, 57, 129, 73, 101, 187],
#  [103, 199, 51, 468, 7, 35, 140],
#  [6, 74, 2, 41, 7, 28, 4, 311, 28, 34, 469, 295, 14],
#  [3, 162, 24, 21, 38, 325, 46, 3, 27, 183, 10, 55],
#  [295, 291, 130, 141, 1, 899, 18, 3, 26, 8, 3],
#  [52, 704, 2, 88, 304, 552],
#  [6,
#   783,
#   10,
#   312,
#   228,
#   177,
#   116,
#   977,
#   1,
#   19,
#   555,
#   6,
#   25,
#   1,
#   296,
#   900,
#   47,
#   6,
#   901,
#   79,
#   10,
#   46,
#   52,
#   1,
#   6],
#  [134, 47, 9, 5, 396, 89],
#  [104, 30, 228, 520, 18, 7, 176, 56, 2, 229, 32, 3],
#  [82, 386, 96, 49, 338, 36, 25, 176, 36, 53, 11, 32, 76, 147, 4, 552],
#  [357, 75, 148, 4, 297, 15, 11],
#  [519, 46, 247, 18, 48],
#  [1, 783, 41, 622, 521, 11, 706, 178, 112, 21, 30, 210, 85, 11, 662],
#  [350, 1, 77, 835, 339, 38, 7, 835, 599],
#  [351,
#   6,
#   86,
#   80,
#   82,
#   80,
#   92,
#   340,
#   581,
#   137,
#   6,
#   8,
#   292,
#   25,
#   121,
#   836,
#   15,
#   55,
#   6,
#   80,
#   23,
#   6,
#   239,
#   19,
#   159,
#   172,
#   148,
#   10,
#   19,
#   470,
#   6,
#   41,
#   88,
#   196,
#   283],
#  [600, 36, 67, 8, 4, 623],
#  [57,
#   501,
#   350,
#   4,
#   126,
#   624,
#   85,
#   5,
#   15,
#   309,
#   1,
#   58,
#   129,
#   358,
#   48,
#   7,
#   1,
#   124,
#   3,
#   22,
#   254,
#   159,
#   3,
#   902,
#   48,
#   903],
#  [6, 160, 192, 160, 250, 15, 34, 284],
#  [176, 3, 56, 2, 90, 11, 359, 601, 121, 22, 23, 582, 121, 234, 8, 5, 205],
#  [430,
#   5,
#   837,
#   216,
#   7,
#   6,
#   27,
#   17,
#   750,
#   978,
#   37,
#   42,
#   7,
#   5,
#   72,
#   451,
#   2,
#   21,
#   904,
#   127,
#   219],
#  [7, 15, 905, 3, 141, 132, 4],
#  [47, 59, 50, 86, 97, 105, 54, 6, 255, 105],
#  [52, 81, 6, 10, 12, 374],
#  [38, 485, 62],
#  [30, 4, 486, 9],
#  [97, 117, 52, 602, 2, 3, 163, 3, 2, 10, 56, 129],
#  [38, 906, 260, 52, 22, 3, 164],
#  [174, 12, 5, 14, 61, 784, 450, 17, 4, 134, 112],
#  [785,
#   73,
#   4,
#   838,
#   397,
#   235,
#   3,
#   17,
#   108,
#   452,
#   2,
#   143,
#   979,
#   2,
#   128,
#   16,
#   128,
#   410,
#   487,
#   603,
#   62],
#  [30, 522, 11, 284, 21],
#  [488,
#   34,
#   980,
#   625,
#   523,
#   6,
#   839,
#   103,
#   14,
#   556,
#   298,
#   625,
#   9,
#   140,
#   471,
#   86,
#   502,
#   149,
#   15,
#   188,
#   86,
#   326,
#   17,
#   245,
#   66,
#   92],
#  [61, 387, 663, 7, 43, 18, 96, 187],
#  [150,
#   11,
#   144,
#   360,
#   411,
#   275,
#   557,
#   80,
#   6,
#   626,
#   627,
#   411,
#   50,
#   840,
#   80,
#   38,
#   251,
#   240,
#   2,
#   50,
#   375],
#  [313, 523, 1, 160],
#  [24, 4, 707, 8, 5],
#  [664, 664, 138, 241, 2, 5, 46, 3, 259, 10, 259],
#  [664,
#   604,
#   15,
#   199,
#   164,
#   160,
#   261,
#   211,
#   25,
#   1,
#   58,
#   376,
#   19,
#   388,
#   6,
#   27,
#   276,
#   15,
#   130,
#   19,
#   50,
#   220,
#   26,
#   6,
#   154,
#   558,
#   751,
#   8,
#   314],
#  [30, 703, 559, 58, 18, 121, 41, 374, 80, 256, 1, 122, 35, 50, 63],
#  [232, 605, 12, 13, 68, 107, 146, 489, 628, 32, 83, 38, 841, 629, 236],
#  [665, 25, 1, 206, 50, 19, 34, 284, 145],
#  [209, 207, 2, 842, 560],
#  [604, 1, 341, 843, 23, 28, 293],
#  [1, 65, 3, 133, 327, 561, 17, 4, 66],
#  [1, 56, 25, 126, 2, 51, 18, 5, 907, 33, 14, 524, 3, 225, 305],
#  [342, 503, 908, 56, 40],
#  [1, 99, 13, 9, 25, 24, 752, 193],
#  [193, 75, 90, 33, 1, 27, 59, 85, 8, 4, 311],
#  [102,
#   844,
#   3,
#   27,
#   240,
#   73,
#   208,
#   45,
#   32,
#   257,
#   205,
#   73,
#   3,
#   242,
#   12,
#   133,
#   909,
#   16],
#  [3, 17, 73, 786, 8, 31, 189, 7, 845, 44, 43, 2, 981, 15, 29, 24, 26, 2, 708],
#  [91, 91, 163, 206, 3, 59, 116, 7, 709, 285],
#  [982,
#   583,
#   80,
#   256,
#   321,
#   9,
#   86,
#   702,
#   525,
#   983,
#   626,
#   583,
#   18,
#   846,
#   328,
#   26,
#   525,
#   411,
#   243,
#   6],
#  [113, 9, 283, 87, 18],
#  [9, 20, 52, 63, 3, 71, 10, 2, 59],
#  [702, 984, 41, 34],
#  [187, 38, 25, 242, 910, 51, 4, 311],
#  [45,
#   451,
#   352,
#   88,
#   753,
#   504,
#   787,
#   37,
#   70,
#   5,
#   306,
#   184,
#   2,
#   21,
#   248,
#   171,
#   137,
#   146,
#   257,
#   205],
#  [7, 389, 32, 21],
#  [39, 17, 33, 6, 71],
#  [119, 63, 2, 132, 431],
#  [135, 47, 9, 4, 661, 56, 3],
#  [93, 2, 184, 606, 504, 130, 35, 5, 336, 36, 70, 83, 2, 2, 322, 216],
#  [114, 3, 90, 20],
#  [1, 60, 82, 14, 555, 3],
#  [135, 25, 1, 106, 188, 607, 1, 55, 64, 67],
#  [579,
#   985,
#   847,
#   88,
#   282,
#   834,
#   710,
#   46,
#   221,
#   9,
#   8,
#   14,
#   25,
#   14,
#   834,
#   170,
#   46,
#   221,
#   911,
#   14,
#   57,
#   125],
#  [256, 25, 38, 233, 505, 100, 58, 2, 50, 12, 256, 7, 412, 12, 12, 562],
#  [91, 91, 506, 1, 61, 8],
#  [304, 59, 185, 711, 35, 36, 116, 214],
#  [46,
#   262,
#   90,
#   11,
#   659,
#   121,
#   99,
#   2,
#   121,
#   22,
#   912,
#   913,
#   121,
#   666,
#   55,
#   20,
#   2,
#   11,
#   373,
#   263,
#   914],
#  [284, 9, 5, 556, 5, 286, 61, 18, 44, 43, 915, 73, 299, 53, 22, 630, 396, 986],
#  [307],
#  [987, 11, 2, 131],
#  [82, 75, 16, 100],
#  [1, 255, 20, 60, 264, 18],
#  [788,
#   200,
#   186,
#   3,
#   208,
#   208,
#   490,
#   521,
#   1,
#   58,
#   116,
#   1,
#   37,
#   71,
#   2,
#   55,
#   20,
#   3,
#   22,
#   394,
#   247,
#   172,
#   29,
#   323,
#   5,
#   916,
#   15,
#   13,
#   66],
#  [28,
#   151,
#   265,
#   93,
#   41,
#   26,
#   41,
#   754,
#   41,
#   133,
#   50,
#   19,
#   146,
#   988,
#   257,
#   205,
#   5,
#   86,
#   321,
#   491,
#   397,
#   712,
#   917,
#   390],
#  [189, 835, 15, 212, 182, 12, 88, 42, 185, 20, 9, 4, 222, 989, 237],
#  [54, 39, 207, 41, 6, 80, 38, 77, 19, 225, 413, 343],
#  [45,
#   127,
#   168,
#   4,
#   8,
#   13,
#   918,
#   15,
#   308,
#   262,
#   22,
#   266,
#   2,
#   229,
#   21,
#   70,
#   229,
#   2,
#   70,
#   238,
#   237,
#   127],
#  [488, 114, 3, 28, 23, 7, 231, 134],
#  [291, 68, 10, 46, 277, 293],
#  [38, 11, 22],
#  [1, 900, 14, 6, 244, 278, 492, 42, 23, 278],
#  [16, 7, 70, 88, 631, 352, 37, 217, 2, 83, 453, 16, 432],
#  [75, 50, 136, 39, 27, 563, 626, 50, 411, 50, 990, 76],
#  [226, 1, 35, 103, 62],
#  [5,
#   919,
#   9,
#   56,
#   4,
#   472,
#   48,
#   11,
#   284,
#   848,
#   597,
#   145,
#   85,
#   14,
#   521,
#   991,
#   31,
#   7,
#   3,
#   17,
#   2,
#   103],
#  [920,
#   51,
#   67,
#   5,
#   710,
#   221,
#   99,
#   8,
#   15,
#   6,
#   110,
#   130,
#   51,
#   67,
#   130,
#   632,
#   59,
#   502,
#   155,
#   373,
#   632],
#  [91, 30, 84, 8, 11, 240, 8, 23, 1, 338, 77, 2, 29, 5, 920, 526],
#  [47,
#   6,
#   921,
#   414,
#   361,
#   124,
#   6,
#   22,
#   564,
#   213,
#   63,
#   1,
#   16,
#   96,
#   9,
#   230,
#   1,
#   180,
#   6,
#   28,
#   8,
#   849],
#  [97, 105, 415, 561, 145, 21],
#  [218, 50, 54, 69, 8, 80, 24, 667, 433, 11, 788, 86, 668, 80],
#  [116, 9, 13, 992, 410, 2, 83, 490, 93, 83, 146, 257, 205, 235, 605],
#  [922,
#   2,
#   205,
#   95,
#   552,
#   40,
#   127,
#   9,
#   45,
#   3,
#   45,
#   633,
#   2,
#   31,
#   219,
#   2,
#   70,
#   50,
#   83,
#   2],
#  [304, 3, 201, 37, 58, 11, 362, 84],
#  [104,
#   713,
#   1,
#   124,
#   3,
#   138,
#   4,
#   245,
#   125,
#   1,
#   242,
#   1,
#   138,
#   59,
#   206,
#   207,
#   2,
#   90,
#   3,
#   65,
#   1,
#   71,
#   750,
#   7,
#   1,
#   71,
#   4,
#   454,
#   286],
#  [135, 434, 1, 71, 2, 3, 32, 11, 341],
#  [608, 229, 86, 552, 21, 755, 416, 669, 432, 527, 217, 62, 48],
#  [6, 23, 417],
#  [408, 507, 2, 272, 79, 5, 23, 1, 58, 4, 278, 344, 21],
#  [13, 45, 435, 9, 266, 2, 36, 68, 5, 2, 2, 28, 7],
#  [1, 106, 99, 69, 473, 2, 993, 69, 201, 116, 436],
#  [139, 63, 29, 6, 239, 19, 159, 10, 100],
#  [38, 25, 565, 29, 2],
#  [1, 455, 2, 59, 670, 7, 709, 12, 285],
#  [69, 175, 79, 279, 62, 92, 1, 55],
#  [1, 25, 351, 9, 67],
#  [350, 1, 60, 266, 12, 13, 16],
#  [32,
#   5,
#   336,
#   9,
#   398,
#   6,
#   634,
#   184,
#   26,
#   635,
#   416,
#   32,
#   122,
#   9,
#   714,
#   2,
#   6,
#   9,
#   33,
#   6,
#   635,
#   6,
#   635,
#   33,
#   6,
#   184,
#   6,
#   87,
#   635],
#  [25, 165, 456, 80, 139, 54, 6, 558, 528, 139],
#  [1, 21, 244, 756],
#  [22, 3, 2, 59, 670],
#  [11, 983, 437, 61, 24, 493, 2, 17, 923, 29, 3, 71, 923, 76, 66],
#  [14, 994, 132, 2, 103, 14, 67, 64, 45, 33, 3, 77, 2, 55, 133, 189],
#  [399, 1, 70, 20, 2, 13, 474, 519],
#  [37, 584, 58, 6, 4, 24, 40, 63],
#  [33, 3, 585, 14, 5, 261, 363, 5, 121, 90, 660, 8, 557, 529, 557, 76, 64],
#  [15,
#   631,
#   208,
#   19,
#   6,
#   122,
#   81,
#   19,
#   40,
#   81,
#   293,
#   19,
#   34,
#   213,
#   77,
#   27,
#   6,
#   68,
#   2,
#   353,
#   475],
#  [97,
#   3,
#   52,
#   33,
#   3,
#   132,
#   4,
#   418,
#   7,
#   14,
#   61,
#   2,
#   757,
#   2,
#   122,
#   136,
#   120,
#   12,
#   5,
#   345,
#   15],
#  [108, 25, 62, 222, 391, 7, 54, 338, 17, 2, 2, 5],
#  [174,
#   12,
#   13,
#   435,
#   586,
#   152,
#   13,
#   95,
#   35,
#   36,
#   924,
#   41,
#   238,
#   141,
#   13,
#   265,
#   24,
#   109,
#   16,
#   235,
#   605,
#   48,
#   636,
#   850,
#   68,
#   636],
#  [1, 138, 995, 6, 4, 494, 110, 603, 194, 64, 530],
#  [287, 267, 531, 7, 1, 715, 24, 2, 637, 51],
#  [247, 129, 115, 2, 227, 24, 315, 150, 387, 27, 3, 28, 116, 8, 56, 129, 438],
#  [272,
#   32,
#   508,
#   419,
#   8,
#   4,
#   66,
#   996,
#   3,
#   35,
#   180,
#   13,
#   321,
#   294,
#   8,
#   40,
#   336,
#   44,
#   43],
#  [107, 29, 10, 4, 107, 987, 11, 364, 2, 107, 89, 9, 105, 364],
#  [221,
#   6,
#   55,
#   115,
#   455,
#   88,
#   789,
#   216,
#   19,
#   190,
#   3,
#   206,
#   337,
#   122,
#   16,
#   21,
#   53,
#   35,
#   36,
#   476],
#  [300,
#   36,
#   20,
#   6,
#   102,
#   17,
#   457,
#   6,
#   71,
#   20,
#   458,
#   6,
#   87,
#   17,
#   129,
#   2,
#   36,
#   156,
#   327,
#   6,
#   22,
#   89],
#  [638,
#   13,
#   925,
#   339,
#   716,
#   12,
#   377,
#   997,
#   926,
#   998,
#   226,
#   1,
#   475,
#   671,
#   16,
#   790,
#   410,
#   758,
#   755,
#   999],
#  [57,
#   181,
#   11,
#   65,
#   1,
#   50,
#   2,
#   223,
#   21,
#   7,
#   242,
#   3,
#   4,
#   134,
#   66,
#   598,
#   15,
#   532,
#   305,
#   7,
#   3,
#   22,
#   11,
#   178,
#   300,
#   161,
#   1,
#   65,
#   3,
#   385],
#  [91, 91, 47, 9, 13, 672, 923],
#  [34,
#   166,
#   9,
#   533,
#   622,
#   2,
#   34,
#   166,
#   8,
#   21,
#   70,
#   50,
#   2,
#   717,
#   62,
#   219,
#   851,
#   852,
#   673],
#  [47, 120, 114, 34, 400],
#  [104, 92, 47, 9, 5, 534, 307],
#  [389,
#   165,
#   352,
#   21,
#   5,
#   927,
#   20,
#   69,
#   928,
#   230,
#   15,
#   14,
#   7,
#   42,
#   32,
#   7,
#   329,
#   53,
#   185,
#   218,
#   213,
#   391],
#  [853, 5, 102, 29, 4],
#  [57, 181, 477, 16, 10, 350],
#  [365,
#   1,
#   509,
#   169,
#   1,
#   58,
#   4,
#   674,
#   58,
#   854,
#   230,
#   41,
#   4,
#   378,
#   469,
#   23,
#   1,
#   639,
#   147,
#   92,
#   76,
#   111,
#   791,
#   34,
#   469],
#  [252, 786, 230, 41, 139, 147],
#  [58, 76, 456, 983],
#  [46, 141, 1, 59, 185],
#  [477,
#   33,
#   708,
#   633,
#   48,
#   4,
#   95,
#   257,
#   155,
#   6,
#   2,
#   718,
#   44,
#   43,
#   26,
#   44,
#   43,
#   29,
#   24,
#   29,
#   23,
#   5,
#   16,
#   556,
#   14,
#   129,
#   535,
#   15,
#   2,
#   132,
#   268,
#   15,
#   5,
#   674,
#   38,
#   85,
#   195,
#   86,
#   855,
#   86,
#   115,
#   108,
#   85],
#  [856,
#   113,
#   30,
#   7,
#   65,
#   2,
#   78,
#   667,
#   532,
#   93,
#   19,
#   137,
#   11,
#   4,
#   127,
#   70,
#   83,
#   2,
#   83,
#   857],
#  [675, 9, 170, 57, 9, 7, 525, 9, 165, 245],
#  [104,
#   414,
#   167,
#   32,
#   11,
#   361,
#   294,
#   52,
#   81,
#   6,
#   42,
#   19,
#   157,
#   10,
#   4,
#   16,
#   8,
#   7,
#   438,
#   31,
#   78,
#   33,
#   295,
#   484,
#   26,
#   759,
#   10,
#   18,
#   40,
#   759,
#   21,
#   65,
#   359],
#  [16, 10, 92, 1, 60, 266, 12, 13, 16],
#  [49, 6, 27, 103, 10, 468, 46, 6, 28, 140],
#  [232,
#   9,
#   25,
#   6,
#   258,
#   24,
#   55,
#   130,
#   14,
#   34,
#   81,
#   93,
#   858,
#   859,
#   494,
#   322,
#   93,
#   322],
#  [118,
#   50,
#   2,
#   929,
#   127,
#   19,
#   401,
#   18,
#   151,
#   5,
#   32,
#   719,
#   41,
#   792,
#   44,
#   43,
#   222,
#   34,
#   719,
#   64],
#  [85, 5, 661],
#  [47, 114, 3, 168, 51, 8, 4, 149, 20, 287, 53, 15, 585, 439],
#  [1, 17, 38, 233, 41, 720],
#  [202,
#   16,
#   48,
#   392,
#   13,
#   41,
#   299,
#   26,
#   420,
#   166,
#   640,
#   510,
#   609,
#   171,
#   288,
#   476,
#   402,
#   151,
#   366,
#   248,
#   358],
#  [17,
#   6,
#   108,
#   233,
#   352,
#   11,
#   339,
#   33,
#   23,
#   174,
#   58,
#   4,
#   793,
#   46,
#   1,
#   11,
#   6,
#   137,
#   1,
#   106,
#   28,
#   41,
#   20],
#  [174, 10, 32, 7],
#  [58,
#   52,
#   14,
#   760,
#   19,
#   103,
#   440,
#   8,
#   5,
#   8,
#   6,
#   27,
#   32,
#   68,
#   2,
#   90,
#   26,
#   257,
#   205,
#   36,
#   6],
#  [104,
#   11,
#   713,
#   167,
#   18,
#   11,
#   149,
#   2,
#   7,
#   39,
#   17,
#   37,
#   108,
#   352,
#   85,
#   379,
#   7,
#   17,
#   4,
#   341,
#   167,
#   165,
#   421,
#   6,
#   52,
#   17,
#   6,
#   108,
#   42,
#   2,
#   359],
#  [38, 133, 361, 263, 132, 843, 15, 233, 18, 26, 197, 7, 157, 174, 2, 309],
#  [102,
#   709,
#   65,
#   183,
#   65,
#   168,
#   6,
#   295,
#   163,
#   64,
#   378,
#   8,
#   65,
#   913,
#   6,
#   102,
#   508,
#   6,
#   37,
#   7,
#   6,
#   55,
#   67,
#   9,
#   2,
#   860,
#   6,
#   914],
#  [587,
#   676,
#   6,
#   707,
#   9,
#   14,
#   3,
#   634,
#   721,
#   166,
#   26,
#   606,
#   16,
#   21,
#   476,
#   402,
#   400,
#   366,
#   95],
#  [109, 11, 677, 109, 59, 116, 7, 267],
#  [761, 521, 69, 115, 218, 486],
#  [31, 78, 85, 5, 149],
#  [62,
#   19,
#   40,
#   494,
#   8,
#   222,
#   151,
#   19,
#   44,
#   43,
#   387,
#   19,
#   41,
#   44,
#   43,
#   536,
#   275,
#   151,
#   44,
#   43,
#   54,
#   316,
#   19,
#   222,
#   97,
#   10,
#   5,
#   530,
#   33,
#   6,
#   81,
#   1,
#   58,
#   140],
#  [202,
#   109,
#   16,
#   13,
#   794,
#   41,
#   299,
#   26,
#   420,
#   166,
#   640,
#   510,
#   609,
#   171,
#   288,
#   402,
#   366,
#   248],
#  [136, 278, 1, 162, 1, 17, 5, 1, 287, 1, 17, 26, 102, 17, 5],
#  [57,
#   459,
#   18,
#   40,
#   66,
#   11,
#   373,
#   1,
#   124,
#   40,
#   3,
#   126,
#   7,
#   762,
#   11,
#   1,
#   99,
#   15,
#   3,
#   7,
#   70,
#   4,
#   385,
#   48,
#   976,
#   5,
#   705,
#   15,
#   3],
#  [49, 460, 38, 77, 2, 485, 32, 52, 3, 162],
#  [361, 6, 55, 9, 581, 912, 103, 188, 373, 7, 478, 137, 6, 65],
#  [130, 27, 930],
#  [161,
#   132,
#   10,
#   10,
#   18,
#   72,
#   10,
#   13,
#   21,
#   161,
#   167,
#   582,
#   7,
#   77,
#   3,
#   21,
#   53,
#   400,
#   353,
#   238,
#   19,
#   70,
#   83],
#  [461, 13, 441, 2, 143, 249, 68, 2, 38, 146, 189],
#  [183, 10, 55, 47, 2, 190, 3, 200, 3, 8, 4, 363, 660, 55, 3, 22, 49],
#  [495,
#   909,
#   41,
#   380,
#   89,
#   9,
#   13,
#   641,
#   66,
#   51,
#   163,
#   786,
#   610,
#   146,
#   189,
#   479,
#   4,
#   793,
#   3],
#  [232, 552, 977, 9, 475, 48, 313, 131, 51, 610, 232, 859, 41, 38, 70],
#  [49, 54, 1, 59, 86, 182, 6, 31],
#  [47,
#   79,
#   247,
#   8,
#   849,
#   32,
#   266,
#   12,
#   675,
#   37,
#   72,
#   84,
#   13,
#   250,
#   7,
#   931,
#   2,
#   678,
#   8,
#   323,
#   5,
#   219,
#   232],
#  [169,
#   10,
#   86,
#   11,
#   668,
#   58,
#   38,
#   279,
#   89,
#   11,
#   408,
#   215,
#   51,
#   23,
#   365,
#   19,
#   328,
#   8,
#   611,
#   26,
#   139],
#  [71, 750, 8, 932, 588, 21, 217],
#  [117,
#   263,
#   82,
#   12,
#   5,
#   278,
#   909,
#   89,
#   9,
#   5,
#   364,
#   15,
#   88,
#   679,
#   12,
#   133,
#   439,
#   786,
#   18,
#   2,
#   662,
#   511,
#   7,
#   90,
#   64,
#   218,
#   152,
#   44,
#   43,
#   102,
#   180,
#   4,
#   722],
#  [433, 11, 537],
#  [35, 36, 85, 54],
#  [462, 34, 933],
#  [1,
#   102,
#   17,
#   101,
#   15,
#   13,
#   8,
#   11,
#   1,
#   61,
#   8,
#   144,
#   46,
#   3,
#   378,
#   10,
#   1,
#   97,
#   3,
#   33,
#   1,
#   168,
#   198,
#   8,
#   11,
#   363],
#  [521, 46, 243, 763, 101, 101],
#  [49, 80, 139, 63, 111, 301],
#  [484, 642, 5, 84, 8, 304],
#  [316, 80, 485, 19, 139, 63, 6, 264],
#  [323, 34, 276, 160, 680, 723, 75, 50, 411, 127, 6],
#  [488, 6, 180, 221],
#  [113, 1, 861, 422, 126, 177, 66, 161, 1, 65, 253],
#  [104, 235, 358, 5, 94, 95, 48, 62, 31, 72, 306, 344, 2, 38, 28, 566, 21],
#  [17, 3, 24, 584, 144, 260, 26, 197],
#  [159, 3, 8, 934, 795, 681, 3, 27, 90, 47, 11, 314, 9, 395],
#  [357, 312, 28, 18, 8, 4, 935, 391],
#  [123, 7, 85, 5, 149, 3, 29, 17, 133, 525, 8, 13, 71, 2, 50, 51, 12, 4, 220],
#  [3, 22, 330, 4, 346, 16, 48, 392, 643, 862, 171, 288, 366, 289, 863],
#  [38, 724, 1, 35, 70, 2, 13, 580],
#  [161, 1, 65, 3, 13, 662, 8],
#  [97, 2, 218, 8, 5],
#  [48, 109, 16, 73, 67, 9, 129, 202, 142, 266, 12, 3],
#  [633,
#   176,
#   13,
#   418,
#   56,
#   4,
#   16,
#   48,
#   480,
#   589,
#   16,
#   2,
#   511,
#   3,
#   63,
#   178,
#   171,
#   137,
#   146,
#   189],
#  [538, 340, 7, 178, 125, 32, 14, 61, 134],
#  [163],
#  [7,
#   175,
#   200,
#   131,
#   230,
#   4,
#   935,
#   512,
#   23,
#   519,
#   24,
#   68,
#   131,
#   51,
#   15,
#   5,
#   764,
#   412,
#   12],
#  [49, 21, 3, 31],
#  [163, 3, 10, 472, 56, 40],
#  [3,
#   17,
#   179,
#   73,
#   4,
#   838,
#   235,
#   88,
#   936,
#   115,
#   3,
#   2,
#   184,
#   4,
#   143,
#   2,
#   461,
#   9,
#   398,
#   37,
#   16],
#  [253, 25, 14, 206, 23, 1, 864, 172],
#  [39, 273, 8, 5, 196, 44, 43, 280],
#  [113, 554, 42, 82, 79, 5, 278, 93],
#  [57,
#   459,
#   11,
#   65,
#   14,
#   61,
#   57,
#   2,
#   90,
#   13,
#   561,
#   18,
#   7,
#   28,
#   13,
#   170,
#   11,
#   1,
#   725,
#   11,
#   7,
#   640,
#   3],
#  [104, 30, 82, 1, 481, 13, 16, 27, 3, 107, 16, 84],
#  [91, 75, 36, 67, 194, 41],
#  [664, 3, 55, 634, 1, 114, 4, 4, 25, 682, 211, 32, 5, 251, 66, 12, 937],
#  [119, 9, 836, 15, 4, 211],
#  [157, 76, 180, 48, 20, 152, 109],
#  [12, 308, 683, 40, 1, 209, 203, 11, 765, 9, 51, 7, 30, 756],
#  [75, 183, 3, 55, 46, 11, 269],
#  [612, 19, 95, 81, 566, 16, 21, 523, 13, 766, 331, 567, 513],
#  [104, 67, 39, 17, 21, 88, 726, 176, 36, 134, 19, 137, 6, 33, 6, 59, 42],
#  [3, 321, 388, 52, 3, 153, 607, 1, 28, 73, 4],
#  [5, 471, 865, 296, 17, 5, 261, 37, 17, 5, 321, 15, 866],
#  [22, 3, 42, 12, 5, 1, 55, 1, 60],
#  [60,
#   18,
#   4,
#   84,
#   48,
#   23,
#   30,
#   24,
#   30,
#   230,
#   89,
#   35,
#   36,
#   201,
#   436,
#   29,
#   3,
#   796,
#   5,
#   684,
#   40,
#   112,
#   85,
#   5,
#   149],
#  [75, 68, 3, 46, 1, 707, 224, 230],
#  [21, 30, 74, 51, 41, 374, 214],
#  [1, 276, 1, 281, 558, 1, 50, 313, 54, 97, 111],
#  [9,
#   56,
#   4,
#   15,
#   4,
#   436,
#   244,
#   81,
#   8,
#   140,
#   261,
#   244,
#   81,
#   703,
#   493,
#   19,
#   938,
#   33,
#   244,
#   159,
#   62,
#   416,
#   244,
#   514,
#   270],
#  [29,
#   3,
#   71,
#   4,
#   94,
#   195,
#   636,
#   96,
#   156,
#   32,
#   45,
#   391,
#   2,
#   101,
#   95,
#   752,
#   45,
#   68,
#   45,
#   685,
#   93,
#   26,
#   16],
#  [1, 27, 132, 14, 42, 67, 44, 43, 51, 15, 11, 408],
#  [49],
#  [259,
#   11,
#   418,
#   842,
#   1,
#   37,
#   300,
#   910,
#   3,
#   73,
#   3,
#   234,
#   32,
#   13,
#   263,
#   867,
#   3,
#   234,
#   7,
#   70,
#   4,
#   385],
#  [24, 399, 31, 275, 28, 4, 442, 2, 284],
#  [633, 176, 13, 418, 56, 4, 16, 48, 480, 589, 16, 2, 511, 13, 63],
#  [104, 3, 37, 2, 244, 56, 2, 55, 33, 3, 234, 32, 5, 93, 45, 32, 135, 26, 38],
#  [30, 31, 993, 21, 868, 85, 5, 363, 939],
#  [52, 403, 5, 29],
#  [404,
#   53,
#   415,
#   1,
#   555,
#   302,
#   15,
#   8,
#   10,
#   77,
#   2,
#   423,
#   4,
#   496,
#   23,
#   36,
#   14,
#   258,
#   191,
#   10,
#   74,
#   7,
#   73,
#   6,
#   162,
#   20,
#   1,
#   28,
#   5,
#   314,
#   2,
#   28,
#   185,
#   5,
#   261],
#  [65, 14, 1, 71, 2, 20, 661, 32, 899],
#  [48, 156, 589, 275, 2, 151, 144],
#  [104, 29, 6, 71, 2, 430, 10, 32, 100, 283, 172, 31, 16, 6, 150, 307],
#  [67, 9, 4, 204, 63, 12, 457],
#  [296,
#   267,
#   667,
#   2,
#   103,
#   5,
#   15,
#   4,
#   20,
#   568,
#   51,
#   15,
#   34,
#   282,
#   7,
#   869,
#   34,
#   228,
#   404,
#   4,
#   797,
#   294,
#   9,
#   116,
#   2,
#   914],
#  [125,
#   115,
#   12,
#   379,
#   66,
#   181,
#   115,
#   59,
#   8,
#   4,
#   271,
#   149,
#   258,
#   3,
#   332,
#   56,
#   5,
#   7,
#   911,
#   13,
#   31,
#   5,
#   764,
#   764,
#   270,
#   798],
#  [177, 49, 80, 417],
#  [187, 231, 1, 106, 50, 333, 2, 168, 213, 308, 173, 3, 381, 642],
#  [19, 7, 334, 644, 1, 481, 13, 539],
#  [54, 281, 80],
#  [41, 31, 727, 37, 2, 51, 4, 393],
#  [161, 6, 6, 19, 177, 18, 119, 124, 49, 103, 188, 15],
#  [135, 1, 59, 2, 12, 7, 60, 333, 2],
#  [45,
#   367,
#   112,
#   451,
#   19,
#   41,
#   4,
#   324,
#   19,
#   184,
#   799,
#   26,
#   753,
#   166,
#   213,
#   317,
#   72,
#   2,
#   288,
#   146,
#   489],
#  [104, 47, 22, 3],
#  [3, 55, 540, 262, 171, 9, 53, 39, 55, 39, 81, 31],
#  [11,
#   65,
#   47,
#   59,
#   14,
#   642,
#   3,
#   23,
#   315,
#   2,
#   227,
#   12,
#   1,
#   58,
#   13,
#   561,
#   18,
#   7,
#   61,
#   126,
#   2,
#   90,
#   172,
#   25,
#   61,
#   645,
#   3,
#   138,
#   386,
#   1,
#   180,
#   3],
#  [3, 17, 179, 4, 870, 420, 496, 2, 128, 16],
#  [158, 163, 24, 9, 5, 53, 293],
#  [54, 139, 81, 6, 164, 21, 590, 433, 144],
#  [30,
#   210,
#   36,
#   78,
#   214,
#   7,
#   1,
#   106,
#   71,
#   2,
#   272,
#   79,
#   40,
#   318,
#   220,
#   91,
#   200,
#   443,
#   89],
#  [1, 17, 4, 147, 46, 1, 272],
#  [119,
#   1,
#   17,
#   2,
#   227,
#   12,
#   11,
#   307,
#   161,
#   3,
#   296,
#   463,
#   84,
#   2,
#   10,
#   124,
#   3,
#   17,
#   4,
#   245,
#   223,
#   11,
#   65],
#  [91, 1, 35, 157, 11, 439],
#  [114, 6, 168, 4, 12, 1, 61, 7, 53, 66, 506],
#  [541, 6, 686, 175, 270, 91, 270, 904],
#  [73,
#   4,
#   838,
#   235,
#   1,
#   60,
#   2,
#   3,
#   20,
#   15,
#   13,
#   542,
#   38,
#   3,
#   22,
#   330,
#   32,
#   4,
#   591,
#   143,
#   16],
#  [1, 60, 8, 16, 3, 92],
#  [1, 60, 31, 5, 919, 50, 67],
#  [3, 17, 108, 219, 800, 476, 402],
#  [57, 181, 434, 47, 22, 3],
#  [1, 206, 182, 5, 96, 145, 21, 107, 70, 4, 142],
#  [5,
#   871,
#   30,
#   62,
#   201,
#   46,
#   147,
#   63,
#   2,
#   757,
#   9,
#   20,
#   368,
#   15,
#   919,
#   1,
#   27,
#   62,
#   2,
#   36,
#   201,
#   46,
#   221,
#   10,
#   2,
#   36,
#   7,
#   20,
#   62,
#   46,
#   543,
#   2,
#   710,
#   42],
#  [119,
#   479,
#   4,
#   15,
#   11,
#   263,
#   801,
#   10,
#   2,
#   597,
#   42,
#   7,
#   59,
#   757,
#   32,
#   172,
#   7,
#   54,
#   801,
#   10,
#   20,
#   30,
#   4,
#   132,
#   172,
#   757,
#   136,
#   120,
#   866,
#   164,
#   251,
#   274,
#   23,
#   3,
#   90,
#   47,
#   30],
#  [107, 107, 168, 51, 48],
#  [253, 49, 137, 44, 43, 280, 7, 940, 93, 6],
#  [64,
#   23,
#   47,
#   81,
#   6,
#   139,
#   81,
#   6,
#   164,
#   47,
#   61,
#   34,
#   66,
#   23,
#   183,
#   10,
#   148,
#   6,
#   197,
#   114,
#   6,
#   332,
#   89,
#   33,
#   24,
#   29,
#   14,
#   21,
#   270],
#  [937, 9, 129, 20, 9, 73, 4, 15, 34, 155, 17, 129, 937],
#  [39, 981, 31],
#  [4, 297, 262, 22, 31, 5, 663, 30, 31, 5, 32, 7],
#  [6, 8, 611, 26, 74, 78, 460, 75, 177, 74, 19, 611, 100],
#  [203, 1, 206, 714, 11, 3, 22, 8, 10, 88, 140],
#  [3, 7, 13, 537, 224, 7, 126, 94, 290, 8],
#  [369, 210, 868, 85, 8, 4, 311],
#  [1, 60, 646, 3, 12, 525, 47, 79, 4, 661, 32, 38],
#  [1, 99, 1, 58, 34, 1, 386, 14, 8, 767, 470, 14, 8, 41, 6, 326],
#  [198, 9, 8, 62, 19, 204, 194, 247, 14, 680, 150, 14],
#  [47, 87],
#  [39, 17, 4, 142, 13, 510, 2, 461, 13, 142, 37, 16],
#  [99,
#   34,
#   184,
#   40,
#   112,
#   8,
#   88,
#   504,
#   68,
#   331,
#   2,
#   21,
#   171,
#   288,
#   476,
#   402,
#   289,
#   238,
#   112],
#  [1, 544, 938, 48, 467, 7, 14, 51, 389],
#  [67,
#   9,
#   378,
#   243,
#   35,
#   528,
#   497,
#   8,
#   647,
#   3,
#   27,
#   268,
#   20,
#   2,
#   5,
#   495,
#   8,
#   7,
#   157,
#   14,
#   2,
#   587],
#  [49, 137, 111, 54],
#  [974, 8],
#  [319, 49, 417],
#  [91, 33, 6, 608, 42, 37, 59, 2, 11, 78],
#  [3, 58, 378, 4],
#  [20, 52, 4, 498, 1, 305, 59, 54],
#  [802, 413, 624, 768, 62, 386, 19],
#  [82, 75, 16, 100],
#  [728, 4, 324],
#  [119, 648, 8, 12, 4, 341, 793],
#  [254, 33, 5, 149, 6, 225, 5, 149, 64, 177],
#  [45, 729, 19, 13, 95, 72, 2, 28, 45, 12, 54, 237, 66, 72, 83, 40, 127, 9, 45],
#  [499,
#   13,
#   280,
#   857,
#   18,
#   380,
#   26,
#   118,
#   19,
#   496,
#   855,
#   7,
#   32,
#   177,
#   45,
#   195,
#   45,
#   16,
#   730,
#   18,
#   731],
#  [36, 25, 75, 29, 52, 1, 17, 2],
#  [3,
#   55,
#   9,
#   333,
#   2,
#   190,
#   3,
#   941,
#   88,
#   789,
#   216,
#   2,
#   168,
#   51,
#   122,
#   14,
#   246,
#   36,
#   16,
#   48,
#   13,
#   95,
#   26,
#   392],
#  [158, 231, 52, 1, 61, 578],
#  [1, 639, 147, 11, 720, 641, 1, 545, 93, 139, 63, 29, 111, 77, 2, 227],
#  [38, 92, 1, 60, 126, 20, 39, 560, 872],
#  [272, 2, 531, 7, 224, 79, 20],
#  [82, 186, 127, 192, 319, 25, 333, 19, 29, 110, 21],
#  [484, 546, 42, 130, 3, 340, 31],
#  [39,
#   22,
#   333,
#   2,
#   190,
#   3,
#   178,
#   303,
#   377,
#   20,
#   3,
#   179,
#   4,
#   354,
#   143,
#   249,
#   16,
#   128,
#   410,
#   487,
#   613,
#   62,
#   366],
#  [476, 503, 38, 77, 285],
#  [32, 13, 360],
#  [91, 54, 22, 3, 264, 2, 307],
#  [761, 509, 230, 48, 144],
#  [97,
#   11,
#   413,
#   243,
#   6,
#   839,
#   8,
#   10,
#   75,
#   267,
#   2,
#   485,
#   8,
#   44,
#   43,
#   1,
#   424,
#   19,
#   11,
#   94,
#   290,
#   266,
#   12,
#   34,
#   93,
#   36,
#   57,
#   181],
#  [52, 9, 13, 339, 152],
#  [102, 478, 118, 66, 170, 341, 59, 515, 54, 323, 842],
#  [1, 160, 127, 1, 19, 401, 8, 160, 1, 23, 645],
#  [132, 20, 151, 41, 224],
#  [38, 25, 3, 255, 10, 3, 234, 74, 194, 3, 58],
#  [109, 508, 48, 160, 296, 12, 909, 56, 232, 580, 296, 13, 32],
#  [40,
#   9,
#   34,
#   662,
#   547,
#   118,
#   19,
#   151,
#   41,
#   222,
#   275,
#   316,
#   536,
#   387,
#   44,
#   43,
#   101,
#   152,
#   1,
#   35,
#   97,
#   34,
#   662,
#   60,
#   266,
#   93],
#  [113,
#   4,
#   486,
#   1,
#   55,
#   9,
#   241,
#   11,
#   2,
#   28,
#   131,
#   110,
#   460,
#   36,
#   493,
#   2,
#   28,
#   4,
#   334,
#   2,
#   993,
#   220],
#  [37, 51, 51, 2, 707, 230, 11, 318, 21],
#  [316,
#   8,
#   11,
#   336,
#   3,
#   34,
#   34,
#   332,
#   34,
#   34,
#   444,
#   34,
#   232,
#   7,
#   367,
#   34,
#   803,
#   539,
#   57,
#   181,
#   117],
#  [47, 208, 403, 14, 103, 2, 28, 2, 5, 15, 4],
#  [113, 121, 81, 24, 355, 569, 220, 23, 75, 724, 177, 78, 382],
#  [68,
#   159,
#   221,
#   425,
#   89,
#   6,
#   27,
#   168,
#   4,
#   552,
#   26,
#   203,
#   64,
#   42,
#   2,
#   6,
#   430,
#   41,
#   37,
#   527,
#   93,
#   32,
#   250,
#   931,
#   942,
#   248,
#   127],
#  [48,
#   104,
#   40,
#   9,
#   13,
#   232,
#   3,
#   17,
#   41,
#   490,
#   3,
#   17,
#   109,
#   16,
#   84,
#   18,
#   2,
#   13,
#   490,
#   7],
#  [97, 10, 197, 295, 564],
#  [52, 63, 3, 99, 848, 17, 14, 77, 2, 55, 46, 1, 141, 36],
#  [47, 120, 176, 14, 400, 2, 4],
#  [28, 32, 5, 277],
#  [711, 642, 4, 445, 192, 39, 227, 8, 4, 623],
#  [543, 2, 144, 51, 204, 462, 41, 873],
#  [545],
#  [27,
#   3,
#   107,
#   168,
#   51,
#   47,
#   120,
#   121,
#   943,
#   8,
#   7,
#   47,
#   208,
#   512,
#   27,
#   14,
#   36,
#   804,
#   64,
#   170,
#   495,
#   2,
#   17,
#   4,
#   93,
#   194],
#  [3, 17, 118, 94, 109, 16],
#  [151,
#   45,
#   453,
#   168,
#   51,
#   79,
#   13,
#   65,
#   173,
#   21,
#   267,
#   151,
#   12,
#   45,
#   68,
#   324,
#   2,
#   289,
#   62,
#   150,
#   151,
#   45,
#   659,
#   353,
#   238,
#   805],
#  [161,
#   47,
#   473,
#   20,
#   66,
#   52,
#   22,
#   3,
#   42,
#   2,
#   1,
#   180,
#   3,
#   154,
#   11,
#   65,
#   679,
#   385,
#   1,
#   124,
#   457,
#   473,
#   119],
#  [12, 57, 25, 38, 26],
#  [555,
#   10,
#   10,
#   132,
#   10,
#   25,
#   8,
#   5,
#   322,
#   15,
#   11,
#   173,
#   46,
#   1,
#   477,
#   191,
#   76,
#   18,
#   11,
#   7,
#   153,
#   797,
#   1,
#   180,
#   6,
#   17,
#   4,
#   245,
#   66,
#   914],
#  [235, 358, 5, 94, 95, 48, 62, 31, 72, 306, 344, 2, 38, 28, 566, 21, 874, 219],
#  [17, 13, 279, 7, 59, 7, 732, 5],
#  [214, 3, 35, 17, 5, 308, 211, 434, 29, 1, 132, 3],
#  [123,
#   253,
#   58,
#   732,
#   256,
#   1,
#   61,
#   578,
#   27,
#   50,
#   12,
#   54,
#   2,
#   394,
#   220,
#   30,
#   45,
#   505,
#   7,
#   479,
#   4,
#   687,
#   220],
#  [9, 137, 24, 226, 3, 141, 17, 255, 10, 733],
#  [86,
#   426,
#   8,
#   140,
#   768,
#   27,
#   1,
#   860,
#   34,
#   719,
#   426,
#   342,
#   29,
#   6,
#   99,
#   1,
#   176,
#   528,
#   472,
#   38,
#   846,
#   137,
#   47,
#   14,
#   834,
#   8,
#   32,
#   129,
#   944],
#  [60, 18, 11, 149],
#  [350, 875, 419, 45, 16, 10],
#  [9, 291, 1, 649, 907, 9],
#  [49, 80, 26, 6, 239, 10, 50, 383, 41, 6],
#  [107, 70, 10, 5, 250, 92],
#  [12,
#   101,
#   721,
#   420,
#   922,
#   17,
#   3,
#   108,
#   39,
#   27,
#   87,
#   236,
#   16,
#   45,
#   806,
#   26,
#   68,
#   84],
#  [11, 115, 108, 23, 120, 1, 1, 37, 209, 328, 1, 305, 635],
#  [592,
#   324,
#   128,
#   34,
#   688,
#   15,
#   992,
#   593,
#   89,
#   68,
#   135,
#   2,
#   21,
#   769,
#   807,
#   95,
#   171,
#   288,
#   769,
#   770,
#   989,
#   289],
#  [802, 158, 33, 13, 24, 136, 51, 7, 167, 412, 2, 11, 271],
#  [20, 570],
#  [734, 771, 179, 277, 4, 785, 8, 88, 354, 143, 303, 16, 21, 143, 410],
#  [212,
#   41,
#   4,
#   324,
#   19,
#   184,
#   663,
#   792,
#   12,
#   567,
#   876,
#   877,
#   629,
#   90,
#   257,
#   205,
#   567,
#   41,
#   38],
#  [1, 55, 98, 378, 10],
#  [3,
#   55,
#   11,
#   594,
#   1,
#   255,
#   3,
#   79,
#   506,
#   218,
#   250,
#   9,
#   69,
#   58,
#   8,
#   849,
#   32,
#   10,
#   178,
#   125,
#   7,
#   543,
#   10,
#   2,
#   159,
#   131,
#   89,
#   31,
#   19,
#   689],
#  [9, 8],
#  [1, 538, 131, 136, 25, 1, 639, 69, 137, 10, 1, 650, 4, 375],
#  [24, 193, 1, 17, 5, 12, 14],
#  [482,
#   54,
#   111,
#   343,
#   100,
#   1,
#   59,
#   86,
#   137,
#   343,
#   878,
#   111,
#   581,
#   595,
#   111,
#   58,
#   92,
#   236,
#   433,
#   111],
#  [64, 582, 474, 189, 3, 90],
#  [114, 634, 15, 3, 17, 101, 29, 3, 55, 15, 164, 197],
#  [3, 13, 329, 260],
#  [554, 599],
#  [164, 14, 2, 749, 15, 62, 7, 22],
#  [5,
#   446,
#   44,
#   43,
#   160,
#   934,
#   531,
#   44,
#   43,
#   44,
#   63,
#   43,
#   60,
#   75,
#   499,
#   313,
#   7,
#   68,
#   3,
#   192,
#   156],
#  [91, 30, 522, 214, 36, 67, 4, 418, 150, 387],
#  [502, 64, 32, 105, 116],
#  [123, 309, 30, 210, 21],
#  [49, 80, 1, 19, 50, 41, 4, 445, 19, 751, 6, 239, 19, 70, 10, 67, 26, 139],
#  [174,
#   12,
#   13,
#   435,
#   586,
#   152,
#   13,
#   95,
#   35,
#   36,
#   924,
#   41,
#   238,
#   141,
#   13,
#   265,
#   24,
#   109,
#   16,
#   235,
#   605],
#  [113, 114, 6, 381, 12, 5, 196],
#  [5, 78, 15, 879, 323, 14],
#  [104,
#   161,
#   6,
#   81,
#   471,
#   2,
#   36,
#   8,
#   405,
#   25,
#   167,
#   23,
#   82,
#   79,
#   220,
#   1,
#   165,
#   347,
#   90,
#   6,
#   156,
#   23,
#   16,
#   10,
#   31,
#   387,
#   65,
#   10,
#   359],
#  [140,
#   772,
#   4,
#   286,
#   61,
#   650,
#   18,
#   44,
#   548,
#   43,
#   44,
#   43,
#   459,
#   118,
#   218,
#   437,
#   378,
#   19,
#   690,
#   151,
#   437,
#   350,
#   1,
#   61,
#   614,
#   46,
#   5,
#   642,
#   240,
#   41,
#   1,
#   61,
#   222,
#   1,
#   61,
#   275,
#   284,
#   1,
#   215,
#   19,
#   140,
#   630,
#   396,
#   316,
#   39,
#   215,
#   19,
#   331,
#   536,
#   39,
#   215,
#   19,
#   4,
#   140,
#   14,
#   93,
#   32,
#   871,
#   33,
#   6,
#   81],
#  [107, 50, 32, 1, 37, 507, 2, 36, 193, 29, 17, 4, 134, 441, 945],
#  [6,
#   81,
#   555,
#   85,
#   140,
#   122,
#   226,
#   714,
#   19,
#   6,
#   29,
#   808,
#   556,
#   447,
#   4,
#   416,
#   298,
#   911,
#   8,
#   4,
#   270],
#  [38, 30, 8, 5, 261, 87, 116, 31, 11, 313, 10, 51, 18, 304, 30, 334],
#  [54, 98, 89, 252, 38, 77, 2, 137],
#  [114, 3, 153, 54, 100, 26, 76, 7],
#  [479, 38, 880, 18, 2, 809, 24, 145, 33, 389, 24, 6, 126],
#  [703, 260, 735, 682, 516, 6],
#  [23, 594, 80, 206, 276, 15, 198, 526, 25, 75, 177, 11, 100],
#  [355, 513, 155, 31, 589, 138, 2, 50, 155, 52, 79, 6],
#  [198, 80, 33, 121, 53, 50, 54, 1, 50, 80],
#  [38, 92, 89, 175, 1, 422],
#  [174, 14, 61, 62, 48, 25, 456, 245, 53, 881, 21, 384, 214],
#  [114, 6, 168, 51, 52, 63, 5, 442, 9, 31, 556, 1, 77, 2, 836, 110, 318, 51],
#  [10,
#   756,
#   212,
#   110,
#   525,
#   57,
#   571,
#   25,
#   788,
#   86,
#   281,
#   239,
#   509,
#   212,
#   4,
#   418,
#   311],
#  [107, 102, 105, 48, 98, 12, 5, 196, 529, 302],
#  [27, 6, 10, 140],
#  [135, 25, 3, 22, 5, 7, 5, 384, 214],
#  [49],
#  [259,
#   6,
#   16,
#   488,
#   6,
#   301,
#   1,
#   796,
#   42,
#   6,
#   53,
#   73,
#   1,
#   77,
#   4,
#   810,
#   48,
#   114,
#   41,
#   178,
#   651,
#   19,
#   89,
#   15],
#  [124, 24, 335, 136, 120, 406, 497, 10, 90, 6, 156, 65, 224],
#  [11, 364, 9, 18, 44, 43, 92],
#  [174, 12, 42, 5],
#  [1, 206, 182, 5, 96, 145, 21, 107, 70, 4, 142],
#  [33, 39, 184, 64, 165, 38, 118, 763, 12, 315, 63],
#  [6, 23, 211, 54, 6, 281, 239, 19, 328, 6, 154],
#  [360, 52, 101, 325],
#  [123, 91, 1, 99, 471, 15, 7],
#  [45,
#   451,
#   8,
#   19,
#   4,
#   811,
#   787,
#   2,
#   184,
#   592,
#   258,
#   68,
#   2,
#   2,
#   348,
#   451,
#   494,
#   876,
#   72,
#   432,
#   171,
#   615,
#   390],
#  [447, 9, 1, 370, 538, 34, 474, 8, 772, 545, 186, 6, 11, 447, 9, 11],
#  [3, 22],
#  [319, 522, 145, 21, 36, 84, 214],
#  [81, 6, 616, 1, 141, 544, 586, 5, 169, 1, 138, 2, 423, 12, 14],
#  [600, 20, 210, 36, 214, 26, 100, 220],
#  [3, 16, 131, 21, 49, 1, 162, 16, 131],
#  [53, 585, 245, 94, 7, 5, 62, 211, 1, 27, 172, 2, 9, 3, 8, 812],
#  [37, 946, 62, 116],
#  [130, 114, 6, 50, 11, 96, 9, 210, 3, 17, 2, 514, 8, 116],
#  [370, 801, 6, 356, 75, 177, 522, 41, 18, 23, 565, 558, 133, 63, 19, 159, 42],
#  [1, 106, 99, 1, 27, 28, 472, 12, 4, 20, 315, 32, 537, 8, 448, 82],
#  [123,
#   5,
#   9,
#   335,
#   4,
#   311,
#   15,
#   4,
#   842,
#   25,
#   14,
#   728,
#   101,
#   629,
#   23,
#   147,
#   369,
#   204,
#   59,
#   204],
#  [82, 92, 89, 1, 464, 59, 2, 331, 1, 17, 562],
#  [59, 147],
#  [3, 35, 36, 8, 5, 240, 15, 20, 286],
#  [1, 60, 18, 5, 149, 2],
#  [839, 478, 268, 8, 4, 175, 103, 19],
#  [37, 186, 3, 129, 580, 2, 129, 599, 32, 8, 14, 9, 20, 145],
#  [40, 423, 9, 44, 548, 43],
#  [60, 62, 12, 57, 95, 407],
#  [81, 6, 863, 8, 33, 39, 159, 39, 27, 50, 19, 11, 284],
#  [5, 9, 12, 809, 11],
#  [151, 3, 17, 13, 95, 762, 323],
#  [252, 58, 139, 2, 212, 97, 199, 54, 111, 38, 77, 2, 59, 8, 192],
#  [499,
#   280,
#   7,
#   857,
#   41,
#   45,
#   18,
#   380,
#   617,
#   18,
#   195,
#   855,
#   813,
#   16,
#   730,
#   18,
#   731,
#   26,
#   947],
#  [3,
#   17,
#   179,
#   4,
#   195,
#   40,
#   9,
#   52,
#   3,
#   28,
#   46,
#   3,
#   184,
#   88,
#   45,
#   736,
#   2,
#   103,
#   440,
#   70,
#   195,
#   2,
#   21,
#   851,
#   852,
#   673,
#   289],
#  [9, 98, 115, 218, 96, 152],
#  [253, 74, 12],
#  [583],
#  [115, 147, 4, 388],
#  [89,
#   9,
#   82,
#   66,
#   33,
#   381,
#   1,
#   61,
#   625,
#   32,
#   3,
#   33,
#   381,
#   1,
#   26,
#   555,
#   3,
#   477,
#   477,
#   37,
#   913,
#   64,
#   34,
#   30,
#   57],
#  [104,
#   95,
#   38,
#   44,
#   43,
#   115,
#   3,
#   8,
#   866,
#   190,
#   18,
#   146,
#   189,
#   14,
#   226,
#   4,
#   134,
#   240,
#   2,
#   70,
#   45,
#   232,
#   2,
#   262,
#   12,
#   133,
#   706,
#   189],
#  [6, 136],
#  [882,
#   7,
#   150,
#   771,
#   59,
#   78,
#   48,
#   20,
#   335,
#   2,
#   11,
#   132,
#   10,
#   374,
#   7,
#   236,
#   10,
#   28,
#   293,
#   12,
#   11,
#   552,
#   22,
#   3,
#   193,
#   13,
#   293,
#   12,
#   20,
#   677,
#   15,
#   173],
#  [24, 20, 1, 55, 15, 471, 262, 42, 116, 22, 87, 51, 15, 448],
#  [11, 279],
#  [49,
#   713,
#   1,
#   14,
#   61,
#   49,
#   1,
#   37,
#   478,
#   136,
#   120,
#   1,
#   17,
#   2,
#   29,
#   110,
#   318,
#   11,
#   720,
#   7,
#   54,
#   17,
#   2,
#   192,
#   25,
#   3,
#   27,
#   16,
#   10,
#   67,
#   773],
#  [89, 30, 24, 25, 24, 45, 626, 6, 31, 34, 587],
#  [1, 138, 995, 6, 4, 494, 110, 603, 194, 64, 530],
#  [304, 6, 631, 296, 150, 903],
#  [1, 60, 578, 15, 74, 241, 2, 12, 11, 256, 139, 63, 6, 74],
#  [1,
#   424,
#   228,
#   36,
#   67,
#   203,
#   33,
#   64,
#   37,
#   8,
#   1,
#   424,
#   28,
#   4,
#   214,
#   37,
#   333,
#   2,
#   36,
#   193,
#   1,
#   77,
#   14],
#  [154, 60, 9, 5, 94, 149, 15],
#  [495,
#   909,
#   41,
#   380,
#   89,
#   9,
#   13,
#   641,
#   66,
#   51,
#   163,
#   786,
#   610,
#   146,
#   189,
#   479,
#   4,
#   793,
#   3],
#  [187, 49, 312, 267, 2, 70, 36, 9, 883, 848, 28, 14, 156],
#  [213, 112, 36],
#  [226, 38, 12, 131],
#  [175, 5],
#  [76, 435, 7, 21, 247, 453, 151, 133, 491],
#  [1, 814, 73, 129, 48, 10, 12, 3, 2, 28, 10, 31, 44, 43, 31, 125],
#  [4, 310, 15, 40, 211, 74, 103, 14, 398, 124, 6, 225, 305, 214, 187],
#  [25, 30, 18, 4, 7, 1, 118, 136, 208, 15, 506, 853, 30, 228, 18, 4],
#  [123,
#   627,
#   119,
#   167,
#   32,
#   11,
#   321,
#   720,
#   122,
#   1,
#   215,
#   51,
#   32,
#   41,
#   4,
#   112,
#   21,
#   234,
#   192,
#   64,
#   108,
#   327,
#   4,
#   112],
#  [3, 517, 36, 119, 185, 110, 20],
#  [52, 602, 2, 105, 97, 5, 985],
#  [36, 193, 2, 313, 13, 580, 39, 186, 506],
#  [35, 3, 56, 2, 36],
#  [15, 231, 515, 3, 28, 116, 436],
#  [45, 435, 93, 308],
#  [259,
#   815,
#   30,
#   421,
#   3,
#   89,
#   1,
#   56,
#   2,
#   70,
#   3,
#   4,
#   7,
#   3,
#   30,
#   578,
#   15,
#   3,
#   7,
#   3,
#   22,
#   679,
#   385],
#  [1, 138, 995, 6, 4, 494, 110, 603, 194, 64, 530],
#  [69, 162, 1, 383, 661, 433, 315, 469, 139, 25, 1, 276, 389, 456, 41, 10, 505],
#  [39,
#   22,
#   333,
#   2,
#   190,
#   3,
#   178,
#   303,
#   377,
#   20,
#   3,
#   179,
#   4,
#   354,
#   143,
#   249,
#   16,
#   128,
#   410,
#   487,
#   613,
#   62,
#   366],
#  [26, 1, 50, 78, 204, 343, 111, 207, 41, 10, 80, 1, 401, 241, 11, 318, 204],
#  [259,
#   11,
#   65,
#   47,
#   473,
#   20,
#   66,
#   1,
#   242,
#   13,
#   119,
#   7,
#   254,
#   161,
#   7,
#   124,
#   20,
#   3,
#   168,
#   110,
#   285,
#   1,
#   180,
#   3,
#   815,
#   4,
#   385],
#  [38, 1, 106, 17, 553, 4, 341, 51, 15, 4],
#  [40,
#   361,
#   403,
#   24,
#   514,
#   8,
#   405,
#   40,
#   361,
#   728,
#   77,
#   63,
#   519,
#   973,
#   51,
#   445,
#   335,
#   406,
#   54,
#   36,
#   42,
#   8,
#   405],
#  [253, 138, 37, 21],
#  [6, 449, 840, 154, 6, 239, 19, 50, 212, 204],
#  [82, 167, 247, 42, 21, 225, 165, 413, 20, 10, 211],
#  [226, 536, 217, 2, 50, 12, 279],
#  [167, 387],
#  [5, 469, 115, 24, 108],
#  [33,
#   708,
#   431,
#   12,
#   4,
#   153,
#   848,
#   212,
#   14,
#   132,
#   193,
#   64,
#   395,
#   1,
#   650,
#   129,
#   18,
#   12,
#   44,
#   43],
#  [7, 28, 110, 233, 84],
#  [342, 130, 6, 31, 64, 37, 56, 137],
#  [304,
#   29,
#   3,
#   55,
#   708,
#   44,
#   43,
#   26,
#   996,
#   493,
#   2,
#   212,
#   88,
#   486,
#   7,
#   145,
#   21,
#   33,
#   39,
#   106,
#   28,
#   4,
#   860,
#   15,
#   64,
#   37,
#   41,
#   53,
#   125],
#  [52, 56, 105],
#  [418, 300, 305, 2, 86, 327, 679, 221, 86, 555, 555, 86, 555, 270, 904],
#  [82, 422, 35, 40, 112, 33, 13, 87, 116],
#  [6, 19, 16, 2, 128, 618, 143, 6, 17, 19, 845, 53, 34, 95, 439, 5],
#  [200,
#   108,
#   48,
#   53,
#   177,
#   7,
#   12,
#   173,
#   40,
#   8,
#   380,
#   463,
#   42,
#   2,
#   10,
#   7,
#   455,
#   33,
#   1,
#   507,
#   23,
#   1,
#   58,
#   5,
#   204,
#   8],
#  [113,
#   27,
#   3,
#   157,
#   10,
#   4,
#   46,
#   3,
#   28,
#   40,
#   77,
#   2,
#   272,
#   2,
#   3,
#   79,
#   40,
#   706,
#   18,
#   5,
#   367],
#  [135, 173, 760, 310, 15, 3, 27, 62, 7, 267, 2, 860, 5],
#  [82, 92, 1, 881, 23, 208, 52, 2, 29],
#  [91, 92, 47, 208, 3, 71],
#  [337,
#   52,
#   3,
#   55,
#   3,
#   347,
#   168,
#   51,
#   122,
#   14,
#   9,
#   157,
#   199,
#   4,
#   16,
#   18,
#   48,
#   392,
#   219,
#   217,
#   248],
#  [202,
#   16,
#   48,
#   13,
#   392,
#   13,
#   794,
#   41,
#   299,
#   26,
#   454,
#   420,
#   166,
#   640,
#   510,
#   609,
#   171,
#   288,
#   476,
#   402,
#   248],
#  [1, 55, 62, 50, 2, 390, 12, 14],
#  [666, 55, 1, 127, 131],
#  [252, 89],
#  [58, 14, 622, 12, 124, 49],
#  [572, 53, 66, 30, 116, 31, 40, 7, 1, 209, 328, 14, 585, 22, 11, 173],
#  [1, 839, 2, 523, 6],
#  [524,
#   274,
#   124,
#   524,
#   274,
#   144,
#   65,
#   524,
#   274,
#   579,
#   258,
#   3,
#   17,
#   53,
#   40,
#   937,
#   937],
#  [350, 266, 12, 13],
#  [5,
#   486,
#   114,
#   110,
#   25,
#   1,
#   56,
#   910,
#   36,
#   8,
#   197,
#   526,
#   196,
#   112,
#   7,
#   69,
#   14,
#   2,
#   199,
#   12,
#   45],
#  [3,
#   22,
#   298,
#   85,
#   88,
#   789,
#   216,
#   85,
#   221,
#   3,
#   55,
#   2,
#   168,
#   51,
#   122,
#   14,
#   9,
#   16,
#   48,
#   4,
#   619,
#   320],
#  [113, 482, 371, 27, 159, 3, 31],
#  [64, 37, 5, 15, 37, 14],
#  [253, 203, 415, 17, 18, 172],
#  [723, 702, 256, 27, 6, 23, 774, 375],
#  [347, 29, 110, 140],
#  [29,
#   3,
#   71,
#   4,
#   94,
#   372,
#   96,
#   737,
#   101,
#   397,
#   280,
#   372,
#   431,
#   7,
#   222,
#   237,
#   112,
#   45,
#   16,
#   26,
#   93,
#   21],
#  [135, 69, 9, 165, 134, 255, 321, 150, 8, 336, 170, 2, 28, 51],
#  [256, 600, 84, 21, 54],
#  [1, 206, 182, 5, 96, 145, 21, 107, 70, 4, 142],
#  [9, 170, 682, 679, 9, 175, 682, 9, 136, 682, 9, 682, 25, 298, 9, 170],
#  [52,
#   22,
#   3,
#   164,
#   8,
#   82,
#   25,
#   75,
#   369,
#   36,
#   8,
#   405,
#   85,
#   14,
#   298,
#   312,
#   31,
#   480,
#   46,
#   29,
#   3,
#   7],
#  [14, 37, 738, 10, 19, 167, 816, 948, 940, 267, 11, 19, 899, 326, 6],
#  [89,
#   9,
#   949,
#   66,
#   243,
#   949,
#   35,
#   6,
#   12,
#   10,
#   70,
#   40,
#   2,
#   53,
#   34,
#   865,
#   25,
#   204,
#   884,
#   10],
#  [30, 421, 6],
#  [14, 399, 36, 254, 1, 17, 21, 35],
#  [119, 1, 338, 24, 59, 54],
#  [1, 198, 80],
#  [69,
#   581,
#   25,
#   1,
#   645,
#   80,
#   817,
#   212,
#   482,
#   80,
#   691,
#   279,
#   25,
#   39,
#   87,
#   41,
#   279,
#   482,
#   4,
#   24,
#   581,
#   409,
#   172,
#   571,
#   252,
#   58,
#   4,
#   310,
#   15,
#   144],
#  [6, 34, 562, 687, 47, 208, 512, 4, 317, 86, 243, 66],
#  [9, 8, 92],
#  [818, 20, 388],
#  [39, 35, 159, 214, 434],
#  [355, 376, 80, 245, 76, 54, 1, 56, 80],
#  [134, 1, 124, 3, 56, 13, 286, 119, 1, 60, 44, 43],
#  [1, 846, 8, 326, 11, 11, 405, 8, 326, 10, 573, 495, 270],
#  [135, 434, 1, 71, 2, 109, 3, 213, 125, 13, 242, 9, 11],
#  [4, 297, 61, 44, 43, 391, 885],
#  [158, 11, 51, 15, 448, 25, 262, 201, 1, 55],
#  [30, 123, 554, 42],
#  [202,
#   3,
#   17,
#   179,
#   4,
#   118,
#   112,
#   45,
#   8,
#   88,
#   606,
#   420,
#   143,
#   72,
#   5,
#   306,
#   128,
#   2,
#   38,
#   171,
#   137,
#   146,
#   489,
#   692],
#  [404, 2, 148, 79, 218],
#  [333, 751, 21, 6, 328, 154, 39, 545],
#  [176,
#   6,
#   620,
#   14,
#   121,
#   483,
#   55,
#   1,
#   138,
#   230,
#   23,
#   121,
#   544,
#   10,
#   192,
#   20,
#   693,
#   2,
#   177],
#  [47, 22, 3, 164, 124, 771, 8, 12, 5, 94, 467, 290, 37, 3, 4, 652, 66],
#  [57, 459, 161, 47, 473, 20, 66, 101, 285, 260, 1, 180, 3, 11, 65],
#  [107, 29, 10, 4, 107, 987, 11, 364, 2, 107, 839, 844, 14, 89, 9, 105, 364],
#  [94,
#   8,
#   205,
#   1,
#   383,
#   750,
#   32,
#   205,
#   340,
#   33,
#   6,
#   56,
#   406,
#   32,
#   10,
#   68,
#   2,
#   248,
#   72,
#   367,
#   353,
#   238],
#  [295, 291, 1, 13, 3, 22, 170, 425],
#  [82, 286, 386, 11, 96, 18, 178, 125, 7, 287, 313, 14, 515, 1, 58, 42],
#  [1, 37, 538, 4, 842, 23, 158],
#  [283, 6, 9, 11, 144, 694, 10, 46, 399, 1, 29, 11, 144, 156],
#  [319,
#   1,
#   276,
#   121,
#   81,
#   160,
#   162,
#   20,
#   35,
#   132,
#   11,
#   662,
#   383,
#   148,
#   10,
#   24,
#   19,
#   791,
#   136],
#  [15,
#   539,
#   465,
#   529,
#   9,
#   24,
#   79,
#   739,
#   150,
#   886,
#   5,
#   142,
#   64,
#   79,
#   739,
#   37,
#   85,
#   887,
#   5,
#   250,
#   270],
#  [26, 17, 3, 386],
#  [134,
#   1,
#   61,
#   247,
#   79,
#   3,
#   37,
#   55,
#   20,
#   4,
#   784,
#   7,
#   292,
#   56,
#   3,
#   35,
#   17,
#   62,
#   5,
#   321,
#   8,
#   173,
#   55,
#   20,
#   6,
#   81,
#   784,
#   7,
#   65,
#   9,
#   566],
#  [47, 81, 111, 74, 2, 70, 14, 2, 10],
#  [104,
#   64,
#   31,
#   53,
#   66,
#   775,
#   1,
#   35,
#   177,
#   667,
#   31,
#   6,
#   796,
#   185,
#   107,
#   227,
#   127,
#   224],
#  [186, 10, 34, 580, 519, 214],
#  [446,
#   20,
#   389,
#   31,
#   4,
#   66,
#   23,
#   1,
#   103,
#   120,
#   15,
#   20,
#   98,
#   287,
#   314,
#   22,
#   3,
#   210,
#   90,
#   131,
#   192,
#   29,
#   3,
#   71,
#   2,
#   59,
#   2,
#   220,
#   6,
#   27,
#   97,
#   10,
#   53,
#   79],
#  [49,
#   5,
#   547,
#   46,
#   22,
#   111,
#   74,
#   2,
#   511,
#   1,
#   99,
#   147,
#   18,
#   258,
#   556,
#   300,
#   347,
#   50,
#   51,
#   32,
#   25,
#   98,
#   45],
#  [47, 315, 403, 14, 103, 2, 28, 14],
#  [59, 2, 11, 78, 12, 76, 178, 63, 1, 464, 29, 198, 10],
#  [73, 254, 126, 155, 164, 119],
#  [45, 127, 435, 48, 610, 189, 519, 204],
#  [49, 36, 49, 1, 337],
#  [167, 11, 978, 52, 79],
#  [119, 1, 814, 73, 2, 11, 125, 15, 194],
#  [1,
#   46,
#   98,
#   403,
#   40,
#   98,
#   52,
#   141,
#   36,
#   4,
#   406,
#   468,
#   574,
#   352,
#   129,
#   66,
#   15,
#   47,
#   457,
#   176,
#   383,
#   8,
#   105,
#   284],
#  [124,
#   274,
#   215,
#   119,
#   31,
#   10,
#   1,
#   87,
#   77,
#   114,
#   6,
#   137,
#   140,
#   418,
#   211,
#   1,
#   386,
#   8,
#   5],
#  [403, 98, 103, 816, 391, 2, 2, 4, 135, 26, 38, 494],
#  [282, 221, 170, 120, 221, 214, 913, 282, 35, 24, 56, 690, 25, 35, 36, 914],
#  [369, 24, 87, 74, 185, 110, 318, 116],
#  [109,
#   16,
#   88,
#   235,
#   216,
#   18,
#   465,
#   73,
#   3,
#   17,
#   179,
#   4,
#   249,
#   354,
#   166,
#   26,
#   618,
#   143],
#  [335, 279, 3, 22, 24, 8, 520, 163],
#  [64, 647, 2, 620, 274, 56, 40, 53, 27, 153, 25, 99, 194, 616, 198, 2, 10],
#  [462, 274, 30, 84, 31, 78, 7, 4, 418, 608, 154],
#  [564,
#   250,
#   34,
#   496,
#   73,
#   315,
#   73,
#   64,
#   488,
#   27,
#   1,
#   182,
#   172,
#   42,
#   342,
#   6,
#   224,
#   773],
#  [5,
#   705,
#   67,
#   4,
#   950,
#   8,
#   5,
#   950,
#   67,
#   9,
#   129,
#   8,
#   5,
#   67,
#   9,
#   4,
#   933,
#   18,
#   5,
#   933,
#   67,
#   22,
#   151,
#   561,
#   819],
#  [30, 31, 144, 109, 16],
#  [117,
#   108,
#   888,
#   2,
#   40,
#   9,
#   88,
#   592,
#   535,
#   2,
#   190,
#   6,
#   72,
#   229,
#   2,
#   717,
#   219,
#   851,
#   852,
#   673],
#  [123, 123, 411, 951, 18, 427, 86, 740, 375],
#  [16, 10, 46, 3, 711, 9, 22, 116, 11, 9, 42, 7, 1, 338, 24, 409, 453],
#  [57, 561, 25, 561, 258, 227, 6, 8, 208, 512],
#  [664, 664, 664, 57, 631, 22],
#  [256, 305, 278, 327, 381, 101, 149, 1, 246, 868, 85],
#  [82, 75, 16, 100],
#  [75, 90, 52, 906, 22],
#  [534,
#   820,
#   32,
#   22,
#   452,
#   2,
#   348,
#   4,
#   821,
#   979,
#   33,
#   3,
#   17,
#   4,
#   952,
#   109,
#   16,
#   128,
#   410,
#   917,
#   390],
#  [47, 59, 98, 27, 28, 14, 141, 177, 456, 2, 337, 627],
#  [84, 8, 174, 12, 199, 42, 7, 199, 53, 7, 126, 90, 3, 214],
#  [3, 17, 118, 94, 109, 16],
#  [123, 91, 1, 35, 59, 156],
#  [29, 6, 71, 19, 159, 42],
#  [252, 281, 77, 2, 182, 34],
#  [97, 130, 3, 953],
#  [645,
#   570,
#   15,
#   4,
#   286,
#   178,
#   112,
#   61,
#   11,
#   11,
#   437,
#   242,
#   10,
#   11,
#   695,
#   422,
#   86,
#   23,
#   114,
#   11,
#   923,
#   1,
#   215,
#   2,
#   144,
#   203,
#   11,
#   114,
#   24,
#   242],
#  [9, 32, 3],
#  [165,
#   1,
#   639,
#   34,
#   933,
#   315,
#   885,
#   25,
#   139,
#   6,
#   370,
#   21,
#   58,
#   268,
#   6,
#   126,
#   343,
#   1,
#   87,
#   558,
#   19],
#  [163, 287, 6, 16, 18, 13, 279],
#  [81, 6, 87, 395, 21],
#  [1, 24, 45, 89, 1, 558, 19, 182, 11, 695, 42],
#  [117, 22, 3, 625, 1, 61, 590, 117],
#  [158, 1, 141, 36, 493, 2, 75, 68, 3, 46, 30, 293, 2, 159, 42],
#  [244, 4, 160, 86, 171, 1, 86, 160, 126, 66, 8],
#  [3,
#   17,
#   179,
#   4,
#   249,
#   428,
#   26,
#   203,
#   354,
#   128,
#   34,
#   428,
#   16,
#   45,
#   18,
#   248,
#   19,
#   83,
#   18],
#  [231],
#  [3, 7, 13, 537, 224, 7, 126, 94, 290, 8],
#  [28, 10, 51, 15, 40, 11, 822, 715, 2, 59, 2],
#  [135, 39, 22, 136],
#  [355, 376, 80],
#  [9, 62, 12, 670, 1, 35, 182, 12, 199, 38, 12, 131],
#  [26, 111, 50, 212, 433, 131, 54, 1, 159, 111, 100, 27],
#  [2, 12, 232, 23, 121, 22, 12, 866],
#  [446, 20, 277, 4, 499],
#  [1, 56, 3, 170, 120, 25, 60, 170, 407],
#  [399, 1, 148, 76, 211, 33, 3, 102, 10],
#  [124, 3, 22, 335, 4, 57, 112, 37, 8],
#  [1,
#   2,
#   212,
#   4,
#   362,
#   64,
#   202,
#   25,
#   4,
#   15,
#   44,
#   43,
#   67,
#   9,
#   38,
#   2,
#   447,
#   44,
#   43,
#   295,
#   11,
#   724],
#  [1, 102, 71, 2, 409, 198],
#  [200, 823, 41, 11, 375],
#  [35, 3, 59, 520, 89, 125],
#  [113, 23, 40, 427, 22, 39, 74, 12, 5, 62, 26, 5, 136],
#  [30, 646, 4, 954, 36, 31, 8, 56, 44, 43, 217],
#  [161, 1, 783, 3, 35, 3, 267],
#  [856,
#   104,
#   414,
#   37,
#   58,
#   4,
#   94,
#   347,
#   137,
#   4,
#   582,
#   621,
#   26,
#   796,
#   4,
#   229,
#   167,
#   884,
#   229,
#   2],
#  [38,
#   147,
#   24,
#   30,
#   861,
#   44,
#   43,
#   644,
#   594,
#   7,
#   36,
#   233,
#   48,
#   11,
#   277,
#   24,
#   2,
#   17,
#   2,
#   32,
#   40,
#   318,
#   40,
#   9,
#   318,
#   163,
#   1,
#   106,
#   97,
#   3],
#  [30, 31, 144, 109, 16],
#  [202, 13, 41, 299, 26, 618, 640, 510, 16, 21, 609, 874, 226, 238, 689],
#  [394, 247, 293, 2, 227, 5, 284],
#  [652, 23, 47, 29, 3, 5, 557, 5],
#  [60, 1, 20, 120],
#  [1,
#   124,
#   3,
#   231,
#   5,
#   15,
#   298,
#   7,
#   677,
#   344,
#   908,
#   131,
#   79,
#   7,
#   191,
#   13,
#   732,
#   7,
#   53,
#   5,
#   321],
#  [450, 6, 14, 305, 144, 51, 607, 1, 35, 225, 804, 996],
#  [389, 129, 7, 176, 48, 5, 479, 38, 308, 1, 37, 102, 56, 121, 102, 77, 25, 38],
#  [17, 3, 741, 8],
#  [11,
#   936,
#   37,
#   5,
#   62,
#   440,
#   39,
#   106,
#   191,
#   15,
#   368,
#   11,
#   816,
#   522,
#   5,
#   211,
#   18,
#   598,
#   44,
#   43,
#   316],
#  [645,
#   570,
#   15,
#   4,
#   286,
#   178,
#   112,
#   61,
#   11,
#   11,
#   437,
#   242,
#   10,
#   11,
#   695,
#   422,
#   86,
#   23,
#   114,
#   11,
#   923,
#   1,
#   215,
#   2,
#   144,
#   203,
#   11,
#   114,
#   24,
#   242,
#   73,
#   1,
#   11,
#   11,
#   407,
#   162,
#   573,
#   126,
#   573,
#   1,
#   901,
#   271,
#   98,
#   995,
#   10,
#   41,
#   279,
#   150,
#   279,
#   98,
#   888,
#   10,
#   2,
#   105,
#   39,
#   215,
#   67,
#   98,
#   162,
#   573,
#   29,
#   6,
#   314,
#   33,
#   1,
#   50,
#   352,
#   5,
#   12,
#   4,
#   623,
#   573,
#   1,
#   8,
#   4,
#   425,
#   98,
#   463,
#   51,
#   222,
#   523,
#   4,
#   86,
#   11,
#   437,
#   11,
#   695,
#   11,
#   11,
#   263,
#   86,
#   11,
#   53,
#   793,
#   7,
#   1,
#   61,
#   266,
#   18,
#   5,
#   819],
#  [134,
#   624,
#   16,
#   2,
#   128,
#   13,
#   249,
#   354,
#   166,
#   26,
#   575,
#   549,
#   384,
#   2,
#   4,
#   273,
#   712,
#   21],
#  [88, 472, 178, 125, 12, 105, 7, 537],
#  [208, 208, 126, 15, 140, 66, 11, 117, 373, 282, 126, 364, 117],
#  [104,
#   713,
#   64,
#   955,
#   22,
#   6,
#   42,
#   12,
#   921,
#   220,
#   167,
#   74,
#   2,
#   4,
#   726,
#   378,
#   5,
#   26,
#   197,
#   32,
#   11,
#   695,
#   12,
#   76,
#   725,
#   23,
#   96,
#   10,
#   33,
#   6,
#   27],
#  [16,
#   2,
#   268,
#   34,
#   280,
#   431,
#   527,
#   217,
#   542,
#   216,
#   85,
#   37,
#   345,
#   429,
#   6,
#   83,
#   248,
#   62],
#  [24, 48, 40, 22, 3, 8, 5],
#  [742, 14, 115, 704, 9, 21, 327, 5, 199, 2, 725, 25, 106, 597],
#  [1, 3, 42, 67, 194],
#  [1, 71, 64, 62, 212, 19, 62, 19, 38, 62, 19, 19],
#  [506, 64, 32, 10, 62, 21, 60, 74, 78],
#  [6,
#   328,
#   328,
#   429,
#   6,
#   422,
#   516,
#   10,
#   154,
#   627,
#   6,
#   103,
#   23,
#   315,
#   19,
#   93,
#   1,
#   276,
#   147,
#   133,
#   327,
#   824,
#   23,
#   177,
#   21,
#   139,
#   399,
#   1,
#   328],
#  [49],
#  [39, 81, 795, 154],
#  [665, 1, 206, 276, 15, 133, 823, 47, 208, 29, 39, 17],
#  [1, 102, 686, 407, 1, 37, 725],
#  [125,
#   115,
#   12,
#   379,
#   66,
#   181,
#   115,
#   59,
#   8,
#   4,
#   271,
#   149,
#   258,
#   3,
#   332,
#   56,
#   5,
#   7,
#   911,
#   13,
#   31,
#   5,
#   764,
#   764,
#   270,
#   798],
#  [226, 30, 355, 14, 8, 273],
#  [114, 6, 58, 20, 570],
#  [41, 8, 77, 949, 18, 34, 542, 97, 34, 72, 265, 2, 576, 12, 26, 754, 12, 19],
#  [45,
#   451,
#   352,
#   88,
#   753,
#   504,
#   787,
#   37,
#   70,
#   5,
#   306,
#   845,
#   2,
#   21,
#   248,
#   171,
#   137,
#   146,
#   189,
#   188],
#  [256, 600, 1, 338, 77, 2, 103, 3, 42, 18, 20, 52, 3, 921, 220],
#  [38, 325, 272, 2, 3, 100],
#  [178,
#   324,
#   19,
#   128,
#   34,
#   688,
#   15,
#   992,
#   593,
#   68,
#   135,
#   2,
#   21,
#   769,
#   807,
#   95,
#   171,
#   288,
#   770,
#   989,
#   289,
#   72,
#   224,
#   26,
#   83],
#  [39,
#   22,
#   2,
#   159,
#   2,
#   516,
#   88,
#   574,
#   300,
#   255,
#   3,
#   8,
#   5,
#   459,
#   300,
#   39,
#   27,
#   50,
#   12,
#   687,
#   150,
#   20],
#  [91,
#   11,
#   175,
#   543,
#   4,
#   7,
#   379,
#   294,
#   258,
#   175,
#   71,
#   110,
#   23,
#   393,
#   18,
#   841,
#   75,
#   97,
#   3,
#   46,
#   121,
#   55,
#   12,
#   193],
#  [371, 33, 3, 42, 194, 816, 151, 40, 36, 4, 325],
#  [39, 17, 2, 182, 67],
#  [1, 60, 74, 2, 812, 89, 35, 36, 269, 62, 31],
#  [1, 58, 12, 31, 1, 329, 3, 24, 44, 63, 43, 689],
#  [498, 124, 6, 81, 254],
#  [1, 209, 145, 40, 680, 864, 738, 262, 42, 204],
#  [123, 583, 80, 39, 50, 18, 427],
#  [163, 106, 3, 207, 31, 701, 2, 90, 33, 3, 28, 13],
#  [1, 71, 879, 147, 37, 7],
#  [1,
#   65,
#   3,
#   23,
#   120,
#   1,
#   209,
#   207,
#   12,
#   40,
#   290,
#   2,
#   73,
#   213,
#   680,
#   760,
#   10,
#   2,
#   298,
#   31,
#   13,
#   763,
#   126,
#   94,
#   290,
#   11,
#   65],
#  [121, 742, 463, 2, 5],
#  [1, 215, 48, 4, 2, 974],
#  [123, 270, 270, 735],
#  [450,
#   3,
#   23,
#   120,
#   46,
#   39,
#   808,
#   7,
#   39,
#   483,
#   28,
#   5,
#   15,
#   13,
#   675,
#   124,
#   3,
#   22,
#   57,
#   3,
#   123,
#   39,
#   22,
#   241,
#   2,
#   323,
#   40,
#   9,
#   5,
#   142,
#   1,
#   186,
#   302,
#   885],
#  [153, 485, 19, 6, 653, 130, 130, 81, 6, 21],
#  [634, 149, 12, 10, 1, 60, 44, 43, 644, 594, 124, 20, 994, 3],
#  [49, 1, 509, 348],
#  [305,
#   550,
#   42,
#   12,
#   825,
#   7,
#   948,
#   56,
#   4,
#   506,
#   21,
#   1,
#   225,
#   25,
#   31,
#   701,
#   64,
#   24,
#   498,
#   677,
#   15],
#  [90, 5, 142, 12],
#  [501, 244, 57, 33, 35, 3, 8, 106, 3, 478, 681, 637, 49, 25, 90, 3, 31, 54],
#  [3,
#   577,
#   620,
#   14,
#   25,
#   147,
#   502,
#   147,
#   857,
#   93,
#   531,
#   21,
#   2,
#   274,
#   20,
#   35,
#   13,
#   314,
#   48,
#   62,
#   72],
#  [1, 60, 646, 334, 66, 227, 1, 60, 24, 119],
#  [52, 63, 141, 1, 97, 11, 294, 2, 36, 201],
#  [1, 51, 4, 630, 85, 4, 486, 32, 5, 261, 724, 243, 61, 32, 4, 121, 102, 20],
#  [46, 114, 408, 28, 84],
#  [365, 571, 1, 276, 788, 2, 50, 51, 1, 581, 148, 105, 260],
#  [27, 111, 16, 10, 31, 454, 454, 2, 132, 193, 356, 200, 42],
#  [12, 6, 68],
#  [225, 56, 333, 192, 244],
#  [29, 1, 1, 300, 1, 401, 14, 84, 8, 5, 402],
#  [183, 67, 36, 879, 183, 67, 36, 879, 40, 677, 15, 560, 23, 27],
#  [59, 2, 812, 546, 51, 88],
#  [52, 141, 1, 328, 279],
#  [104, 161, 329, 51, 941],
#  [49, 137, 6, 54],
#  [6,
#   22,
#   2,
#   5,
#   321,
#   95,
# ...
#  [638,
#   13,
#   925,
#   339,
#   716,
#   12,
#   377,
#   997,
#   926,
#   998,
#   226,
#   1,
#   475,
#   671,
#   16,
#   790,
#   410,
#   758,
#   755,
#   999],
#  [987, 11, 2, 131],
#  [9, 170, 682, 679, 9, 175, 682, 9, 136, 682, 9, 682, 25, 298, 9, 170, 270],
#  [64, 44, 43, 91, 116, 123, 141, 1, 70, 78, 12],
#  [417, 41, 959, 10, 78],
#  [3, 35, 13, 265, 862, 5, 196, 12, 7, 109, 90, 6, 654],
#  [9, 7, 10, 20, 224, 9, 816, 42, 5, 73, 39, 384],
#  [104,
#   40,
#   9,
#   39,
#   35,
#   36,
#   959,
#   3,
#   4,
#   45,
#   96,
#   152,
#   8,
#   4,
#   935,
#   15,
#   302,
#   243,
#   35,
#   157,
#   3,
#   129,
#   2,
#   53,
#   5],
#  [1, 60, 24, 335, 105, 152, 350],
#  [184, 4, 354, 166, 143, 26, 4, 143, 688, 618],
#  [71, 750, 8, 932, 588, 21, 217, 692],
#  [61, 5, 327],
#  [591,
#   271,
#   533,
#   622,
#   15,
#   593,
#   2,
#   36,
#   179,
#   37,
#   530,
#   41,
#   398,
#   889,
#   331,
#   21,
#   70,
#   2,
#   717,
#   133,
#   697,
#   146,
#   308,
#   189],
#  [27, 3, 268, 12, 743, 3, 70, 172, 230, 12],
#  [282,
#   9,
#   497,
#   65,
#   314,
#   9,
#   497,
#   81,
#   497,
#   632,
#   155,
#   173,
#   9,
#   497,
#   865,
#   23,
#   36,
#   8,
#   849,
#   57,
#   125,
#   155,
#   373,
#   632],
#  [6, 42, 8, 447, 336, 62, 211, 243, 32, 86, 310, 532],
#  [1, 653, 6, 846, 626, 627, 91, 80, 251, 302, 411],
#  [6,
#   22,
#   2,
#   5,
#   321,
#   95,
#   762,
#   216,
#   8,
#   5,
#   205,
#   12,
#   770,
#   237,
#   454,
#   302,
#   429,
#   3,
#   70,
#   83,
#   2],
#  [49, 80],
#  [930,
#   73,
#   208,
#   988,
#   73,
#   6,
#   56,
#   38,
#   19,
#   744,
#   6,
#   27,
#   203,
#   70,
#   19,
#   777,
#   72,
#   350,
#   2,
#   770],
#  [540, 6, 42, 19, 6, 234, 210, 16, 10, 72, 326, 91],
#  [244, 102, 180, 5, 624, 72, 34, 669, 2, 942, 2, 267, 854, 289],
#  [91, 91, 54, 388, 110],
#  [38, 92, 69, 9, 797, 92, 228, 959, 56, 40, 666, 620, 101, 15, 415, 142, 9, 4],
#  [62,
#   138,
#   13,
#   95,
#   3,
#   22,
#   2,
#   551,
#   2,
#   5,
#   349,
#   636,
#   346,
#   95,
#   12,
#   45,
#   16,
#   5,
#   95,
#   551,
#   45,
#   18],
#  [351, 1, 58, 127, 778, 38],
#  [198, 80, 509, 604, 15, 199, 80],
#  [3, 22, 21, 53, 605, 28, 15, 425, 26, 2, 13, 96, 50, 2, 610, 257, 205, 38],
#  [57, 32, 5, 6, 246, 177, 4, 19, 430, 5, 684, 93, 93, 83, 127, 353],
#  [109, 111, 58, 63],
#  [253, 46, 22, 111, 646, 1, 344, 8],
#  [1, 33, 13, 96, 215, 1, 138, 2, 97, 3, 1, 65, 3, 161],
#  [5,
#   480,
#   570,
#   9,
#   5,
#   480,
#   127,
#   9,
#   65,
#   5,
#   480,
#   9,
#   500,
#   4,
#   345,
#   155,
#   242,
#   6,
#   480],
#  [126, 364, 258, 53, 34, 632, 59, 502],
#  [1, 27, 16, 8, 44, 43, 217, 33, 295, 49],
#  [49],
#  [698,
#   20,
#   264,
#   185,
#   5,
#   9,
#   14,
#   4,
#   124,
#   3,
#   17,
#   4,
#   134,
#   66,
#   274,
#   81,
#   74,
#   254,
#   116,
#   590,
#   436],
#  [404, 18, 20, 66],
#  [117, 15, 53, 74, 2, 393, 40, 322, 136],
#  [82, 61, 8, 5],
#  [735, 127, 54, 138],
#  [13, 46, 1, 77, 14],
#  [73,
#   8,
#   22,
#   67,
#   101,
#   12,
#   10,
#   76,
#   48,
#   380,
#   20,
#   4,
#   25,
#   258,
#   87,
#   153,
#   380,
#   18,
#   14],
#  [29,
#   3,
#   71,
#   654,
#   737,
#   101,
#   397,
#   280,
#   68,
#   7,
#   4,
#   94,
#   372,
#   96,
#   12,
#   62,
#   622,
#   237,
#   112,
#   16,
#   21,
#   26,
#   93,
#   12,
#   643,
#   156],
#  [802, 119, 125, 125],
#  [1, 901, 23, 24, 101, 871, 69, 52, 79, 10],
#  [3, 17, 118, 94, 109, 16],
#  [13,
#   339,
#   115,
#   108,
#   32,
#   533,
#   45,
#   68,
#   490,
#   2,
#   37,
#   72,
#   5,
#   306,
#   828,
#   2,
#   38,
#   171,
#   288,
#   146],
#  [117, 108, 888, 2, 40, 9, 88, 592, 535, 2, 190, 6, 72, 229, 2, 717],
#  [357, 3, 714, 85, 26, 87, 241, 201, 240],
#  [1, 17, 208],
#  [135,
#   121,
#   11,
#   474,
#   30,
#   74,
#   2,
#   5,
#   396,
#   100,
#   557,
#   35,
#   8,
#   2,
#   835,
#   100,
#   175,
#   26,
#   18],
#  [52, 29, 6, 73, 77, 19, 33, 6, 209, 29, 14, 174],
#  [134, 1, 341, 843, 23, 28, 293],
#  [54, 34, 668, 47],
#  [23, 64, 2, 36, 286, 20, 121, 3, 8, 47, 22, 3, 37, 616, 104],
#  [46, 3, 37, 401, 8, 5, 744, 11, 152, 7, 5, 35, 518, 145],
#  [47, 797, 2, 153, 20, 1, 309, 3, 102, 99, 31, 53, 18, 52, 1, 929, 3],
#  [761, 355, 376, 31, 78, 24, 74, 51, 244, 608],
#  [23, 20, 760, 472, 110, 233],
#  [98, 994, 77, 101, 547],
#  [1,
#   507,
#   2,
#   242,
#   3,
#   4,
#   126,
#   94,
#   290,
#   7,
#   1,
#   507,
#   2,
#   272,
#   2,
#   3,
#   79,
#   110,
#   2,
#   29,
#   32,
#   46,
#   7,
#   1,
#   25,
#   8,
#   292,
#   75,
#   132,
#   4,
#   574,
#   2,
#   12,
#   20,
#   1,
#   124,
#   457,
#   9,
#   57,
#   32,
#   3,
#   161,
#   7,
#   1,
#   65,
#   253],
#  [1,
#   255,
#   105,
#   1,
#   138,
#   4,
#   196,
#   112,
#   98,
#   779,
#   30,
#   210,
#   1,
#   255,
#   105,
#   64,
#   37,
#   4,
#   313,
#   351,
#   2,
#   36,
#   79,
#   25,
#   98,
#   287,
#   827],
#  [167, 23, 120, 1, 176, 153, 940, 70, 6, 4, 120, 324, 15, 9, 24, 218, 326],
#  [117, 163, 3, 230, 1, 206, 597, 23, 1, 655, 2, 597],
#  [1, 58, 56, 44, 43, 1, 27, 28, 110, 133, 100, 436, 28, 743, 3, 225, 56],
#  [252, 207, 41, 10, 8, 611, 1, 301, 563, 222],
#  [22, 67, 617, 183, 10, 55, 109, 169, 1, 165, 77, 2, 344, 395],
#  [45,
#   12,
#   367,
#   112,
#   195,
#   265,
#   41,
#   34,
#   542,
#   213,
#   112,
#   37,
#   72,
#   195,
#   2,
#   576,
#   28,
#   957,
#   7,
#   97,
#   34,
#   766,
#   146,
#   958,
#   257,
#   205,
#   692,
#   265,
#   289],
#  [462, 274, 37, 4, 494],
#  [113, 161, 1, 538, 3, 463, 520, 12, 4, 680, 7, 54, 3, 52, 704],
#  [319, 1, 545, 108, 67, 194, 3, 71, 2, 50, 12, 5, 1, 27, 16, 42, 2, 511],
#  [871, 9, 33, 5, 9, 617, 31, 178, 121, 212, 5, 12, 31, 432],
#  [3, 12, 506],
#  [34,
#   9,
#   21,
#   721,
#   34,
#   196,
#   494,
#   9,
#   122,
#   8,
#   5,
#   19,
#   530,
#   72,
#   34,
#   530,
#   2,
#   57,
#   984],
#  [161,
#   17,
#   3,
#   58,
#   443,
#   233,
#   2,
#   182,
#   42,
#   7,
#   7,
#   75,
#   157,
#   3,
#   14,
#   84,
#   46,
#   3,
#   28,
#   78],
#  [6,
#   27,
#   184,
#   606,
#   15,
#   513,
#   549,
#   593,
#   213,
#   112,
#   21,
#   72,
#   5,
#   306,
#   303,
#   2,
#   960,
#   146,
#   189],
#  [49, 323, 81, 6, 67, 8, 78],
#  [926, 26, 197, 56, 20],
#  [],
#  [104, 157, 199, 84, 88, 243, 39, 12, 48],
#  [732,
#   32,
#   46,
#   14,
#   843,
#   37,
#   401,
#   557,
#   8,
#   5,
#   250,
#   240,
#   7,
#   14,
#   35,
#   518,
#   3,
#   529,
#   820,
#   5,
#   152,
#   9,
#   11,
#   152,
#   419,
#   3,
#   182,
#   20,
#   152,
#   5,
#   35,
#   564],
#  [65, 115, 38, 115, 38, 115, 38, 258, 6, 17, 228, 8, 34, 173, 270],
#  [228, 693, 4, 579, 679, 437, 25, 5, 62, 76, 437],
#  [14, 464, 177, 429, 19, 73, 333, 19, 836, 284, 51, 9, 20, 49],
#  [245, 207, 141, 3, 36, 145, 21, 30, 24, 210, 423, 13, 253, 55],
#  [295, 291, 1, 60, 4, 7, 35, 722, 3, 32, 7],
#  [27, 365, 139, 2, 28, 41, 105],
#  [7, 860],
#  [53, 723, 57, 524, 14, 2, 718],
#  [1, 65, 2, 907, 7, 11],
#  [5,
#   211,
#   32,
#   6,
#   27,
#   2,
#   5,
#   2,
#   191,
#   197,
#   25,
#   5,
#   623,
#   121,
#   17,
#   14,
#   46,
#   6,
#   183,
#   50,
#   295,
#   14],
#  [24, 165, 541, 17, 38, 263, 30],
#  [119,
#   269,
#   28,
#   5,
#   754,
#   435,
#   26,
#   636,
#   18,
#   95,
#   68,
#   265,
#   26,
#   2,
#   21,
#   678,
#   51,
#   72,
#   83,
#   353,
#   238],
#  [9, 20, 18, 5, 38, 64],
#  [28, 241, 8, 7, 699, 2, 791, 145, 763, 44, 43, 7, 31, 204, 145],
#  [350,
#   124,
#   13,
#   66,
#   9,
#   74,
#   1,
#   165,
#   1,
#   464,
#   17,
#   2,
#   3,
#   79,
#   40,
#   1,
#   17,
#   110,
#   20,
#   1,
#   209,
#   40,
#   345,
#   1,
#   60,
#   51,
#   15,
#   53,
#   841,
#   166,
#   1,
#   55,
#   40,
#   9,
#   4,
#   63,
#   12,
#   3,
#   175,
#   25,
#   1,
#   17,
#   2,
#   183,
#   3,
#   55],
#  [612, 195, 372, 346, 96, 9, 13, 16, 431, 400, 366, 16, 48, 289, 714, 630],
#  [20, 47, 176, 3, 56, 2, 36],
#  [319, 620, 139, 6, 165, 581, 137, 160, 127, 1, 186],
#  [30, 254, 124, 3, 22, 175],
#  [141, 1, 97, 11, 294, 24, 2, 59, 515, 56, 44, 43],
#  [113, 22, 3, 625, 32, 10, 93, 10],
#  [39, 17, 186, 12, 235, 216, 899, 2, 34, 474, 519, 12, 439, 190, 199],
#  [68, 10, 46, 3, 28, 230, 106, 16, 11, 813, 335],
#  [193, 25, 521, 11, 695, 35, 36, 395, 18, 1, 106, 165, 77, 4, 570],
#  [698, 5, 250, 122, 9, 646, 307, 12, 199],
#  [1, 60, 247, 48, 13, 73, 1, 131, 64, 129, 142],
#  [2, 28, 13, 45, 68, 282, 2, 21, 171, 137, 390, 289, 62, 77, 236, 16],
#  [338, 119, 167, 67],
#  [124, 3, 22, 24, 335, 20, 677, 15, 66, 17, 76, 32, 843, 15, 2, 332],
#  [3, 287, 17, 2, 97, 10, 20, 21, 30, 578, 557, 389, 74, 2, 83, 53, 13],
#  [3, 58, 285, 8, 3, 35, 28, 213, 211, 8, 173, 8, 19, 26, 151, 644],
#  [961, 80, 69, 239, 19, 50, 137, 89, 829, 23, 328, 733, 80, 1, 6],
#  [163, 5, 466, 9, 8, 448],
#  [545, 2, 212, 100, 1, 313, 154, 62, 58, 518, 8, 160, 459, 6, 301, 144, 154],
#  [60, 175, 164, 8, 62, 25, 17, 2, 423],
#  [38, 490, 18, 105, 96, 30, 14, 21],
#  [5, 19, 486, 9, 298, 25, 76, 294, 9, 8, 42, 44, 43, 688, 220, 33],
#  [52, 290, 7, 47, 208],
#  [73,
#   4,
#   838,
#   235,
#   1,
#   60,
#   2,
#   3,
#   20,
#   15,
#   13,
#   542,
#   38,
#   3,
#   22,
#   330,
#   32,
#   4,
#   591,
#   143,
#   16],
#  [34,
#   74,
#   19,
#   7,
#   384,
#   2,
#   4,
#   273,
#   712,
#   2,
#   128,
#   634,
#   166,
#   248,
#   62,
#   2,
#   678,
#   51,
#   72,
#   224,
#   2],
#  [30, 87, 661, 89, 413, 66],
#  [202,
#   13,
#   95,
#   152,
#   115,
#   108,
#   330,
#   4,
#   143,
#   249,
#   16,
#   48,
#   392,
#   128,
#   487,
#   613,
#   62,
#   366],
#  [36, 185, 8, 4, 311, 37, 110, 318, 51],
#  [34,
#   166,
#   9,
#   533,
#   622,
#   2,
#   34,
#   166,
#   8,
#   21,
#   70,
#   50,
#   2,
#   717,
#   62,
#   219,
#   127,
#   851,
#   852,
#   673],
#  [49, 1, 276, 1, 58, 14, 54, 6, 239, 10, 19, 59, 21, 26, 139],
#  [22, 3, 49, 52, 602, 2, 56, 40],
#  [44, 43, 280, 25, 1, 138, 2, 83, 920, 204],
#  [15, 403, 69, 17, 101, 166, 260],
#  [495,
#   142,
#   40,
#   9,
#   4,
#   592,
#   190,
#   535,
#   3,
#   17,
#   495,
#   490,
#   266,
#   51,
#   88,
#   235,
#   758,
#   41,
#   999,
#   16,
#   21],
#  [30,
#   165,
#   82,
#   1,
#   577,
#   177,
#   493,
#   19,
#   29,
#   40,
#   825,
#   124,
#   6,
#   27,
#   168,
#   129,
#   124,
#   777,
#   74,
#   49],
#  [460, 1, 106, 99, 1, 27, 198, 42, 116, 55, 33, 3, 71, 10, 2, 597, 241, 7],
#  [23, 313, 13, 7, 33, 3, 138, 29],
#  [5,
#   480,
#   570,
#   9,
#   5,
#   480,
#   127,
#   9,
#   65,
#   5,
#   480,
#   9,
#   500,
#   4,
#   345,
#   155,
#   242,
#   6,
#   480],
#  [49, 25, 1, 301, 31, 275],
#  [51,
#   11,
#   263,
#   22,
#   12,
#   5,
#   765,
#   518,
#   7,
#   577,
#   36,
#   84,
#   515,
#   44,
#   43,
#   23,
#   225,
#   45,
#   2,
#   50,
#   7,
#   757,
#   20,
#   44,
#   43,
#   688],
#  [1,
#   175,
#   276,
#   136,
#   774,
#   76,
#   24,
#   10,
#   6,
#   281,
#   239,
#   147,
#   49,
#   74,
#   19,
#   505,
#   130,
#   58,
#   702],
#  [25, 1, 8, 459],
#  [365, 571, 177, 562, 80, 169, 1, 50, 611, 118],
#  [46, 3, 22, 341, 309, 35, 470],
#  [91, 3, 22, 5, 62, 361, 266, 8, 360],
#  [3, 87, 31, 5, 663],
#  [563, 41, 80],
#  [511,
#   243,
#   687,
#   54,
#   3,
#   127,
#   10,
#   1,
#   35,
#   16,
#   42,
#   150,
#   144,
#   26,
#   30,
#   74,
#   2,
#   28,
#   11,
#   9],
#  [52, 89, 745, 745, 9, 299, 23, 38, 144],
#  [247, 165, 7],
#  [195, 491, 977, 884, 265, 2, 576, 942, 265, 2, 576, 146, 958, 257, 205, 219],
#  [30, 164, 92, 86, 86, 15, 86, 626, 15, 86, 58, 516, 316, 86, 334],
#  [82,
#   2,
#   6,
#   192,
#   27,
#   212,
#   12,
#   11,
#   408,
#   192,
#   53,
#   19,
#   341,
#   118,
#   975,
#   427,
#   86,
#   740,
#   417],
#  [1, 276, 177, 87, 58, 86, 86, 75, 177, 164, 92, 86],
#  [184,
#   4,
#   290,
#   15,
#   41,
#   4,
#   15,
#   34,
#   688,
#   721,
#   845,
#   88,
#   606,
#   504,
#   303,
#   72,
#   513,
#   2,
#   960,
#   288,
#   146,
#   189],
#  [125, 158, 193, 211, 565, 144, 14, 51, 54],
#  [158, 39, 58, 76, 42, 12, 199],
#  [54, 111, 148, 408, 2, 182, 111, 42, 343, 252, 239, 19, 514, 429, 275],
#  [6, 81, 5, 471, 579, 361, 381, 6, 81, 11, 414, 59, 7, 137, 10, 8, 5, 363],
#  [53, 160, 321, 41, 34, 562, 482],
#  [357, 29, 3, 87, 71, 2, 28, 233],
#  [583],
#  [3, 27, 132, 4, 8, 163, 29, 121, 28, 53, 5, 57, 318],
#  [1,
#   65,
#   3,
#   3,
#   55,
#   27,
#   3,
#   225,
#   14,
#   403,
#   14,
#   132,
#   13,
#   1,
#   242,
#   14,
#   403,
#   11,
#   65,
#   1,
#   399,
#   159,
#   3,
#   8,
#   13,
#   632,
#   385],
#  [780, 9, 830, 54, 830, 9, 5, 250, 15, 780],
#  [1, 483, 28, 34, 598, 127, 9, 421, 70, 14, 192],
#  [128, 4, 468, 37, 16, 21, 17, 3, 179],
#  [104, 40, 9, 48, 47, 22, 3],
#  [47, 315, 194, 3, 28, 93, 37, 515, 196, 962],
#  [167, 82, 781, 178, 651, 14, 34, 14, 61, 10, 14, 61, 26, 6, 10, 1, 99, 6],
#  [9, 34, 185],
#  [130, 81, 39, 283],
#  [42, 200, 108, 12, 56, 302],
#  [723, 56, 3, 17, 208, 176, 3, 56, 2, 50, 18, 4, 374, 552, 196, 112],
#  [1, 449, 78, 86, 873, 375],
#  [9, 226, 57],
#  [187, 1, 176, 25, 585, 1, 56, 298, 4, 361],
#  [295, 291, 1, 60, 4, 7, 35, 722, 3, 32, 7],
#  [1,
#   694,
#   17,
#   6,
#   73,
#   4,
#   190,
#   18,
#   189,
#   2,
#   70,
#   45,
#   232,
#   2,
#   48,
#   232,
#   38,
#   2,
#   44,
#   43],
#  [25, 3, 8, 849, 32, 10],
#  [24, 905, 62, 76, 66, 76, 32, 8, 76, 345, 39, 27, 301],
#  [29,
#   743,
#   3,
#   71,
#   3,
#   55,
#   52,
#   5,
#   22,
#   39,
#   138,
#   4,
#   272,
#   733,
#   40,
#   112,
#   79,
#   52,
#   138,
#   2,
#   344,
#   3,
#   260,
#   213,
#   112,
#   147,
#   27,
#   1,
#   5,
#   40,
#   149,
#   52,
#   79,
#   20,
#   149,
#   29,
#   743,
#   30,
#   831,
#   15,
#   335,
#   261,
#   32,
#   3,
#   213,
#   112,
#   7,
#   4,
#   44,
#   43,
#   569,
#   994,
#   5,
#   277,
#   87,
#   247,
#   8,
#   150,
#   118],
#  [47, 114, 6, 55, 52, 1],
#  [7, 22, 633, 21, 106, 180, 5, 406, 16, 31, 527, 217, 19, 83, 453, 16, 432],
#  [126, 94, 290, 2, 6, 7, 34, 537, 258, 40, 94, 290, 470, 890, 7, 2, 34, 173],
#  [49, 74, 2, 223, 124, 1, 27, 159, 105],
#  [169, 1, 71, 14, 2, 36, 13, 211],
#  [761, 30, 24, 1, 581, 92, 571],
#  [158, 145, 75, 470, 11, 775],
#  [208, 133, 126, 15, 5, 66, 1, 242, 3, 126, 364],
#  [97, 10, 244, 3, 8, 546, 52, 53, 2, 28, 21],
#  [1,
#   106,
#   55,
#   6,
#   7,
#   6,
#   106,
#   55,
#   10,
#   70,
#   229,
#   2,
#   717,
#   21,
#   7,
#   168,
#   805,
#   251,
#   62,
#   219,
#   127,
#   851,
#   852,
#   673,
#   248,
#   644,
#   26,
#   185],
#  [40, 441, 9, 254, 129, 24, 2, 29, 136, 120],
#  [69, 446, 104, 7, 2, 28, 13, 891, 84, 2, 31, 4],
#  [30, 778, 282, 30],
#  [104, 541, 81, 6, 92, 6, 89],
#  [91,
#   488,
#   34,
#   45,
#   59,
#   2,
#   11,
#   78,
#   7,
#   175,
#   694,
#   1,
#   500,
#   186,
#   474,
#   2,
#   131,
#   175,
#   305,
#   59,
#   501,
#   940,
#   36,
#   45,
#   89],
#  [545, 87, 73, 252, 59, 84, 611, 823],
#  [82, 79, 20, 40, 9, 11, 766, 96, 7, 1, 483, 929, 14, 65, 955],
#  [148, 531, 26, 200, 255, 5, 570, 56, 826, 512, 154],
#  [853, 64, 108, 4, 315, 66, 30, 37, 71, 2, 42, 7, 103, 4],
#  [235,
#   216,
#   39,
#   596,
#   2,
#   132,
#   4,
#   643,
#   2,
#   3,
#   25,
#   234,
#   2,
#   29,
#   23,
#   109,
#   16,
#   2,
#   544],
#  [47, 1, 653, 114, 111, 92, 73, 252, 87, 8, 611],
#  [67, 5, 15, 6, 42, 34, 891],
#  [1, 24, 590, 509, 281, 239, 19, 50, 23, 382, 817],
#  [3, 22, 145, 462, 42],
#  [25, 75, 177, 74, 19, 611, 18, 982, 11, 668, 77, 19, 103, 751],
#  [45, 195, 26, 855, 32, 118, 533, 45, 224, 489, 280, 45, 16, 730, 18, 26, 16],
#  [20,
#   458,
#   48,
#   2,
#   75,
#   36,
#   247,
#   4,
#   240,
#   2,
#   514,
#   241,
#   67,
#   23,
#   1,
#   106,
#   17,
#   2,
#   84,
#   7,
#   73,
#   1,
#   17,
#   521,
#   11,
#   672,
#   472,
#   48],
#  [76, 15, 5, 8, 42, 805, 20, 443, 4, 181],
#  [135,
#   1,
#   741,
#   2,
#   70,
#   2,
#   132,
#   14,
#   25,
#   498,
#   463,
#   84,
#   23,
#   30,
#   84,
#   8,
#   405,
#   499,
#   31,
#   5,
#   136,
#   1,
#   864,
#   166,
#   8,
#   53,
#   11],
#  [82, 200, 24, 881, 2, 20, 240, 1, 424, 29, 23, 156, 165, 82],
#  [309,
#   34,
#   23,
#   356,
#   271,
#   35,
#   415,
#   85,
#   34,
#   21,
#   477,
#   102,
#   148,
#   342,
#   69,
#   23,
#   120,
#   465],
#  [17, 4, 383, 31, 5, 8, 772, 26, 4, 511, 38, 4, 2, 36, 4, 511],
#  [3, 8, 13, 363, 1, 77, 4, 297],
#  [30, 285, 56],
#  [47, 22, 3, 242, 3, 4, 134, 962],
#  [57, 223, 9, 79, 5, 292, 115, 2, 4, 20, 5, 35, 7, 268, 33, 3, 71, 2, 55, 133],
#  [113, 52, 47, 79, 13, 741, 92],
#  [38, 431, 490, 481, 431],
#  [19, 956, 1, 653, 25, 136, 883, 343, 1, 239, 774, 76],
#  [853, 466, 14, 30, 2, 589],
#  [148, 33, 6, 846, 159, 42],
#  [408, 446, 5, 42],
#  [113, 21, 60, 45, 3, 27, 16, 10],
#  [34,
#   9,
#   21,
#   196,
#   494,
#   5,
#   341,
#   4,
#   177,
#   26,
#   137,
#   68,
#   4,
#   177,
#   26,
#   137,
#   2,
#   57,
#   984],
#  [12,
#   850,
#   850,
#   12,
#   12,
#   282,
#   282,
#   12,
#   6,
#   25,
#   6,
#   12,
#   10,
#   70,
#   2,
#   53,
#   34,
#   263,
#   10,
#   33,
#   6,
#   56,
#   10,
#   33,
#   6,
#   28,
#   84,
#   118,
#   6,
#   81,
#   8,
#   19,
#   6,
#   77,
#   110,
#   118,
#   2,
#   963,
#   151,
#   6,
#   81,
#   746,
#   19,
#   208,
#   41,
#   6,
#   222,
#   9,
#   309,
#   2,
#   6,
#   267,
#   14],
#  [484, 1, 17, 4, 94, 21],
#  [3, 193, 13, 483, 182, 14, 42],
#  [123, 73, 26, 64],
#  [30, 8, 307, 114, 3, 28, 11, 68],
#  [82, 75, 16, 100],
#  [45, 663, 28, 41, 45, 48, 5, 567, 367, 28, 34, 567, 93, 630, 54, 792, 12],
#  [3, 22, 24, 10, 25, 3, 17, 2, 11, 107],
#  [89,
#   9,
#   949,
#   66,
#   243,
#   949,
#   35,
#   6,
#   12,
#   10,
#   70,
#   40,
#   2,
#   53,
#   34,
#   865,
#   25,
#   204,
#   884,
#   10],
#  [1, 11, 440, 823, 27, 111, 28, 14, 131],
#  [47, 1, 653, 648, 8, 92, 362, 21, 100, 54, 137, 343, 30],
#  [252, 581, 97, 10, 47, 1, 653, 30, 24, 31, 78, 8, 92, 691, 139],
#  [69, 446, 104, 7, 2, 28, 13, 891, 84, 2, 31, 4],
#  [24, 260, 138, 253, 598, 7],
#  [546, 18, 5, 763, 48, 130, 39, 3, 230],
#  [57, 501, 40, 9, 47, 22, 3],
#  [38, 648, 8, 12, 20],
#  [37, 21, 538, 13, 142, 14, 91, 92],
#  [113, 3, 27, 423, 32, 503, 62, 44, 43],
#  [1, 35, 36, 795, 396, 103, 53, 48, 67],
#  [1, 77, 2, 59, 78, 7, 157, 3, 110, 57],
#  [319, 111, 24],
#  [3, 17, 129, 495, 235, 216, 16, 806, 21],
#  [554, 42, 124, 3, 138, 4, 134, 810, 29, 17, 4, 962],
#  [563, 56, 356, 80, 39, 509, 159, 8, 990, 54, 111, 281, 558, 2, 59, 51],
#  [158, 75, 267, 2, 197, 42],
#  ...]

# %%
sequences_matrix.shape # matrix 4736 x 150 
# (after padding sequences 150 equally)
# Out:
# (4736, 150)

# %%
# RNN
# Define the RNN structure.

def RNN():
    inputs = Input(name='inputs',shape=[max_len])
    layer = Embedding(max_words,50,input_length=max_len)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %%
# Call the function and compile the model.

model = RNN()
model.summary()
model.compile(loss='binary_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 150)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 150, 50)           50000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                29440
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 96,337
# Trainable params: 96,337
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/anaconda3/envs/dl_101/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
import keras
import pydot as pyd
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

keras.utils.vis_utils.pydot = pyd

#Visualize Model

def visualize_model(model):
    return SVG(model_to_dot(model).create(prog='dot', format='svg'))
#create your model
#then call the function on your model
visualize_model(model)

from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# WARNING:tensorflow:From /usr/local/anaconda3/envs/dl_101/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 3788 samples, validate on 948 samples
# Epoch 1/10
# 3788/3788 [==============================] - 23s 6ms/step - loss: 0.3392 - accuracy: 0.8691 - val_loss: 0.1688 - val_accuracy: 0.9705
# Epoch 2/10
# 3788/3788 [==============================] - 22s 6ms/step - loss: 0.0971 - accuracy: 0.9786 - val_loss: 0.0538 - val_accuracy: 0.9863
# Epoch 3/10
# 3788/3788 [==============================] - 21s 6ms/step - loss: 0.0478 - accuracy: 0.9855 - val_loss: 0.0468 - val_accuracy: 0.9884
# Epoch 4/10
# 3788/3788 [==============================] - 23s 6ms/step - loss: 0.0329 - accuracy: 0.9900 - val_loss: 0.0677 - val_accuracy: 0.9852

# %%
# Process the test set data.
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %%
# Evaluate the model on the test set.

accr = model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 836/836 [==============================] - 2s 3ms/step

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# Test set
#   Loss: 0.061
#   Accuracy: 0.981
